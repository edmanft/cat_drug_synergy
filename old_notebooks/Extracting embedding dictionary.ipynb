# %% [markdown]
# <a href="https://colab.research.google.com/github/edmanft/Drug_Synergy/blob/main/Extracting%20embedding%20dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loading packages

# %%
import fastbook
fastbook.setup_book()
# Out:
# /home/mgonzalez/.local/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
from fastbook import *

from pandas.api.types import is_string_dtype, is_numeric_dtype, is_categorical_dtype
from fastai.tabular.all import *
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

from dtreeviz.trees import *
from IPython.display import Image, display_svg, SVG
from collections import Counter
import seaborn as sns
import xgboost
from xgboost import XGBRegressor

pd.options.display.max_rows = 20
pd.options.display.max_columns = 8

# %% [markdown]
# # Loading Data 1

# %%
path = "/content/gdrive/MyDrive/archivos_tfm/drug_comb_commutative.csv"
df_drug_comb = pd.read_csv(path, index_col = 0)

# %%
df_drug_comb.head(10)
# Out:
#   Cell line name Compound A Compound B  Max. conc. A  ...  QA  Combination ID  \
# 0          BT-20        AKT     ADAM17           1.0  ...   1      ADAM17.AKT
# 1        CAL-120        AKT     ADAM17           1.0  ...  -1      ADAM17.AKT
# 2         CAL-51        AKT     ADAM17           1.0  ...   1      ADAM17.AKT
# 3        DU-4475        AKT     ADAM17           1.0  ...  -1      ADAM17.AKT
# 4        HCC1143        AKT     ADAM17           1.0  ...  -1      ADAM17.AKT
# 5        HCC1187        AKT     ADAM17           1.0  ...   1      ADAM17.AKT
# 6        HCC1428        AKT     ADAM17           1.0  ...  -1      ADAM17.AKT
# 7        HCC1806        AKT     ADAM17           1.0  ...   1      ADAM17.AKT
# 8        HCC1937        AKT     ADAM17           1.0  ...   1      ADAM17.AKT
# 9          HCC70        AKT     ADAM17           1.0  ...   1      ADAM17.AKT
#
#    Challenge  Dataset
# 0        ch1    train
# 1        ch1    train
# 2        ch1    train
# 3        ch1    train
# 4        ch1    train
# 5        ch1    train
# 6        ch1    train
# 7        ch1    train
# 8        ch1    train
# 9        ch1    train
#
# [10 rows x 16 columns]

# %%
df_drug_comb.columns
# Out:
# Index(['Cell line name', 'Compound A', 'Compound B', 'Max. conc. A',
#        'Max. conc. B', 'IC50 A', 'H A', 'Einf A', 'IC50 B', 'H B', 'Einf B',
#        'Synergy score', 'QA', 'Combination ID', 'Challenge', 'Dataset'],
#       dtype='object')

# %%
print("Splits: ",df_drug_comb['Dataset'].unique())
print("Challenge: ",df_drug_comb['Challenge'].unique())
# Out:
# Splits:  ['train' 'LB' 'test']
# Challenge:  ['ch1']

# %% [markdown]
# In this dataset we have a train/test/Leaderboard split. Also, all of our data refers to challege 1, so we can just drop that column later.

# %%
# A little bit of data analysis
df_drug_comb.describe()
# Out:
#        Max. conc. A  Max. conc. B       IC50 A          H A  ...          H B  \
# count   6078.000000   6078.000000  6078.000000  6078.000000  ...  6078.000000
# mean       2.891955      3.788416     0.993535     2.953543  ...     2.976279
# std        9.056161     11.862565     3.988749     3.694176  ...     3.739967
# min        0.003000      0.003000     0.000001     0.000000  ...     0.000000
# 25%        1.000000      1.000000     0.095057     0.471782  ...     0.447019
# 50%        1.000000      1.000000     0.380878     1.253943  ...     1.224778
# 75%        3.000000      3.000000     1.000000     3.185872  ...     3.228787
# max       75.000000     75.000000    75.000000    10.000000  ...    10.000000
#
#             Einf B  Synergy score           QA
# count  6078.000000    6078.000000  6078.000000
# mean     47.596612       9.651604     0.691675
# std      36.131568     130.497366     0.826996
# min       0.000000    -588.220700    -3.000000
# 25%      12.129980      -6.080299     1.000000
# 50%      45.895864       8.068145     1.000000
# 75%      83.060818      25.387880     1.000000
# max     100.000000    6737.175000     1.000000
#
# [8 rows x 10 columns]

# %% [markdown]
# We will choose to train only in high quality data, meaning QA=1.

# %%
df_drug_comb = df_drug_comb[df_drug_comb["QA"] == 1]
print("Values of QA:", df_drug_comb["QA"].unique())
# Out:
# Values of QA: [1]

# %% [markdown]
# We drop QA, Combination ID and Challenge.

# %%
df_drug_comb.columns
# Out:
# Index(['Cell line name', 'Compound A', 'Compound B', 'Max. conc. A',
#        'Max. conc. B', 'IC50 A', 'H A', 'Einf A', 'IC50 B', 'H B', 'Einf B',
#        'Synergy score', 'QA', 'Combination ID', 'Challenge', 'Dataset'],
#       dtype='object')

# %%
df_drug_comb.drop(['QA','Challenge'], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# SettingWithCopyError                      Traceback (most recent call last)
# <ipython-input-13-7a10f575290e> in <module>()
# ----> 1 df_drug_comb.drop(['QA','Challenge'], axis = 1, inplace = True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151
#    4152         if inplace:
# -> 4153             self._update_inplace(obj)
#    4154         else:
#    4155             return obj
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _update_inplace(self, result, verify_is_copy)
#    4237         self._clear_item_cache()
#    4238         self._mgr = result._mgr
# -> 4239         self._maybe_update_cacher(verify_is_copy=verify_is_copy)
#    4240
#    4241     @final
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _maybe_update_cacher(self, clear, verify_is_copy)
#    3508
#    3509         if verify_is_copy:
# -> 3510             self._check_setitem_copy(stacklevel=5, t="referent")
#    3511
#    3512         if clear:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _check_setitem_copy(self, stacklevel, t, force)
#    3931
#    3932         if value == "raise":
# -> 3933             raise com.SettingWithCopyError(t)
#    3934         elif value == "warn":
#    3935             warnings.warn(t, com.SettingWithCopyWarning, stacklevel=stacklevel)
#
# SettingWithCopyError:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# It gives a warning but it has succesfully dropped QA and Challenge columns from the DataFrame.

# %% [markdown]
# # Loading Data 2

# %%
df_drug_comb.head()
# Out:
#   Cell line name Compound A Compound B  Max. conc. A  ...      Einf B  \
# 0          BT-20        AKT     ADAM17           1.0  ...   91.593425
# 2         CAL-51        AKT     ADAM17           1.0  ...   76.656479
# 5        HCC1187        AKT     ADAM17           1.0  ...  100.000000
# 7        HCC1806        AKT     ADAM17           1.0  ...   48.650054
# 8        HCC1937        AKT     ADAM17           1.0  ...   92.188029
#
#    Synergy score  Combination ID  Dataset
# 0      29.540390      ADAM17.AKT    train
# 2       0.315422      ADAM17.AKT    train
# 5      -0.801993      ADAM17.AKT    train
# 7     -26.733250      ADAM17.AKT    train
# 8      32.165520      ADAM17.AKT    train
#
# [5 rows x 14 columns]

# %%
df_drug_comb.columns
# Out:
# Index(['Cell line name', 'Compound A', 'Compound B', 'Max. conc. A',
#        'Max. conc. B', 'IC50 A', 'H A', 'Einf A', 'IC50 B', 'H B', 'Einf B',
#        'Synergy score', 'Combination ID', 'Dataset'],
#       dtype='object')

# %%
dep_var = 'Synergy score'
procs = [Categorify, FillMissing]

# %%
# We shuffle the data
df_drug_comb = df_drug_comb.sample(frac=1).reset_index(drop=True)
df_drug_comb.head(10)
# Out:
#   Cell line name Compound A     Compound B  Max. conc. A  ...      Einf B  \
# 0     MDA-MB-453    AKT_SGK           FGFR           1.0  ...   27.685312
# 1     MDA-MB-453        AKT         ADAM17           1.0  ...  100.000000
# 2      NCI-H2085  Topotecan         PIK3CB           1.0  ...   25.268242
# 3        HCC1187     ADAM17  PIK3CB_PIK3CD          75.0  ...   74.499763
# 4        NCI-H23      ALK_2           TOP2           3.0  ...    4.944053
# 5        HT-1197       FGFR            AKT           3.0  ...   58.538453
# 6          SW780    MAP2K_1    BCL2_BCL2L1           3.0  ...   21.648698
# 7       NCI-H747       BCL2        MAP2K_1           3.0  ...   32.233236
# 8     MDA-MB-468    MAP2K_3          PIK3C           0.3  ...   33.381054
# 9         CAL-51      PIK3C        AKT_SGK           1.0  ...   28.692948
#
#    Synergy score        Combination ID  Dataset
# 0      -6.499640          AKT_SGK.FGFR    train
# 1      16.049800            ADAM17.AKT    train
# 2      10.448870      PIK3CB.Topotecan    train
# 3       3.157859  ADAM17.PIK3CB_PIK3CD    train
# 4       9.824909            ALK_2.TOP2    train
# 5      -3.891046              AKT.FGFR     test
# 6      57.326460   BCL2_BCL2L1.MAP2K_1    train
# 7      23.481400          BCL2.MAP2K_1    train
# 8      13.039870         MAP2K_3.PIK3C    train
# 9      17.158580         AKT_SGK.PIK3C    train
#
# [10 rows x 14 columns]

# %% [markdown]
# We create the train/test/LB splits and then create a copy of our dataset without the Combination ID.
# We want to retain the Combination ID because we use it for our Weighted Pearson metric.

# %%
dataset_size = df_drug_comb.shape[0]
complete_list = np.arange(dataset_size, dtype = int)

train_idx = complete_list[df_drug_comb["Dataset"]=="train"]
test_idx = complete_list[df_drug_comb["Dataset"]=="test"]
LB_idx = complete_list[df_drug_comb["Dataset"]=="LB"]

# For now we ignore the LB split

splits = (list(train_idx),list(test_idx))

df_drug_comb.drop(['Dataset'], axis = 1, inplace = True)
df_nocomb = df_drug_comb.drop(['Combination ID'], axis = 1)

# %%
print("With Combination ID: ", df_drug_comb.columns)
print("Without Combination ID:", df_nocomb.columns )
# Out:
# With Combination ID:  Index(['Cell line name', 'Compound A', 'Compound B', 'Max. conc. A',
#        'Max. conc. B', 'IC50 A', 'H A', 'Einf A', 'IC50 B', 'H B', 'Einf B',
#        'Synergy score', 'Combination ID'],
#       dtype='object')
# Without Combination ID: Index(['Cell line name', 'Compound A', 'Compound B', 'Max. conc. A',
#        'Max. conc. B', 'IC50 A', 'H A', 'Einf A', 'IC50 B', 'H B', 'Einf B',
#        'Synergy score'],
#       dtype='object')

# %%
cont,cat = cont_cat_split(df_nocomb, 1, dep_var=dep_var)
to = TabularPandas(df_nocomb, procs, cat, cont, y_names=dep_var, splits=splits)

# %%
len(to.train),len(to.valid)
# Out:
# (3590, 1089)

# %%
xs,y = to.train.xs,to.train.y
valid_xs,valid_y = to.valid.xs,to.valid.y

# %% [markdown]
# ### Understanding xs, ym valid_xs, valid_y

# %%
xs.columns
# Out:
# Index(['Cell line name', 'Compound A', 'Compound B', 'Max. conc. A',
#        'Max. conc. B', 'IC50 A', 'H A', 'Einf A', 'IC50 B', 'H B', 'Einf B'],
#       dtype='object')

# %%
valid_xs.head(10)
# Out:
#     Cell line name  Compound A  Compound B  Max. conc. A  ...     Einf A  \
# 5               32          32           2           3.0  ...  78.399574
# 11               7          49           2           1.0  ...  54.700432
# 19              51          40          27           1.0  ...  93.800095
# 33              35           2           1           1.0  ...  17.701706
# 40              28          36          11           3.0  ...   0.000000
# 46              70          69          32           3.0  ...   6.651286
# 48               7           3           2           1.0  ...   0.000000
# 54              65          50          36           3.0  ...  90.494576
# 59              43          29           3           3.0  ...  72.035904
# 66              21          18           2           0.1  ...   0.097044
#
#       IC50 B        H B      Einf B
# 5   0.099498   2.531000   58.538452
# 11  0.235409   1.182479   34.658417
# 19  1.000000   0.000000  100.000000
# 33  0.540880   4.851464   73.495689
# 40  3.000000   0.103996    0.764862
# 46  0.008543   2.302804    0.000000
# 48  0.817985   0.573871    0.000000
# 54  0.152743   0.472341   73.164726
# 59  3.000000   0.108414   49.027077
# 66  0.093099  10.000000   42.666550
#
# [10 rows x 11 columns]

# %%
test_df.head(10)
# Out:
#    Cell line name Compound A Compound B  Max. conc. A  ...        H B  \
# 5         HT-1197       FGFR        AKT           3.0  ...   2.531000
# 11         BT-549   PIK3CA_4        AKT           1.0  ...   1.182479
# 19        MFM-223    MAP2K_1       ERBB           1.0  ...   0.000000
# 33       Hs-578-T        AKT     ADAM17           1.0  ...   4.851464
# 40        HCC1954        IAP     BCL2L1           3.0  ...   0.103996
# 46     NCI-SNU-16        WNT       FGFR           3.0  ...   2.302804
# 48         BT-549      AKT_1        AKT           1.0  ...   0.573871
# 54       NCI-H358     PIK3CB        IAP           3.0  ...   0.472341
# 59     MDA-MB-157     ESR1_1      AKT_1           3.0  ...   0.108414
# 66        HCC1395  CSNK2A1_2        AKT           0.1  ...  10.000000
#
#         Einf B  Synergy score  Combination ID
# 5    58.538453      -3.891046        AKT.FGFR
# 11   34.658416      12.835160    AKT.PIK3CA_4
# 19  100.000000     -18.621690    ERBB.MAP2K_1
# 33   73.495692      11.609180      ADAM17.AKT
# 40    0.764862      56.365480      BCL2L1.IAP
# 46    0.000000      -4.284508        FGFR.WNT
# 48    0.000000       9.382423       AKT.AKT_1
# 54   73.164729     -29.514740      IAP.PIK3CB
# 59   49.027076       9.354758    AKT_1.ESR1_1
# 66   42.666551      31.198440   AKT.CSNK2A1_2
#
# [10 rows x 13 columns]

# %% [markdown]
# It converts categorical variables into numerical ones.

# %%
to.classes["Compound A"]
# Out:
# ['#na#', 'ADAM17', 'AKT', 'AKT_1', 'AKT_SGK', 'ALK', 'ALK_2', 'ALK_IGFR', 'ATM', 'ATR_4', 'BCL2', 'BCL2L1', 'BCL2_2', 'BCL2_BCL2L1', 'BCL2_BCL2L1_BCL2L2', 'BRAF_M', 'BRAF_M2', 'CHEK1', 'CSNK2A1_2', 'CarboTaxol', 'Carboplatin', 'Chloroquine', 'Cisplatin', 'Doxorubicin', 'EG5', 'EGFR', 'EGFR_2', 'ERBB', 'ESR1', 'ESR1_1', 'ESR1_3', 'FASN', 'FGFR', 'Gemcitabine', 'HDAC_4', 'HSP90', 'IAP', 'IGFR_3', 'IGFR_4', 'JAK', 'MAP2K_1', 'MAP2K_3', 'MTOR', 'MTOR_1', 'MTOR_3', 'Oxaliplatin', 'PARP1', 'PIK3C', 'PIK3CA_3', 'PIK3CA_4', 'PIK3CB', 'PIK3CB_PIK3CD', 'PIK3C_2', 'PIK3C_MTOR', 'PIM1', 'PIP5K1', 'PTK2', 'Proteasome_2', 'SLC16A4', 'SN38', 'SYK', 'TKI', 'TNF', 'TNFSF10', 'TNKS_PARP6', 'TOP2', 'TOP2_2', 'Topotecan', 'Vinorelbine', 'WNT']

# %%
df_nocomb["Compound A"].unique()
# Out:
# array(['AKT_SGK', 'AKT', 'Topotecan', 'ADAM17', 'ALK_2', 'FGFR', 'MAP2K_1', 'BCL2', 'MAP2K_3', 'PIK3C', 'SLC16A4', 'PIK3CA_4', 'HDAC_4', 'TNKS_PARP6', 'CSNK2A1_2', 'ATR_4', 'CarboTaxol', 'HSP90',
#        'ESR1', 'MTOR_1', 'IAP', 'EGFR', 'AKT_1', 'PIM1', 'BCL2_BCL2L1', 'Vinorelbine', 'BCL2L1', 'ERBB', 'PIK3CB_PIK3CD', 'WNT', 'ALK_IGFR', 'EG5', 'PIK3CA_3', 'PIK3CB', 'Gemcitabine', 'ESR1_1',
#        'EGFR_2', 'PIP5K1', 'ALK', 'PARP1', 'IGFR_3', 'CHEK1', 'Cisplatin', 'MTOR_3', 'Doxorubicin', 'TNFSF10', 'FASN', 'TNF', 'SYK', 'PIK3C_2', 'TOP2_2', 'Chloroquine', 'PIK3C_MTOR', 'BCL2_2',
#        'BRAF_M2', 'BRAF_M', 'IGFR_4', 'TOP2', 'JAK', 'ESR1_3', 'TKI', 'PTK2', 'Proteasome_2', 'ATM', 'MTOR', 'Oxaliplatin', 'Carboplatin', 'SN38', 'BCL2_BCL2L1_BCL2L2'], dtype=object)

# %% [markdown]
# When we do to.classes there appears a "#na#" item that does not appear in the original DataFrame. Ask Pablo about that.

# %%
y
# Out:
# 0       -6.499640
# 1       16.049801
# 2       10.448870
# 3        3.157859
# 4        9.824909
#           ...
# 5264    14.633900
# 5266    18.675730
# 5267    28.432369
# 5268     1.742103
# 5269    47.096230
# Name: Synergy score, Length: 3590, dtype: float32

# %% [markdown]
# We create a permutated valid_xs to make the evaluation conmutative

# %%
valid_xs_perm = pd.DataFrame()
valid_xs_perm[['Cell line name', 'Compound A', 
               'Compound B', 'Max. conc. A',
       'Max. conc. B', 'IC50 A', 
       'H A', 'Einf A', 
       'IC50 B', 'H B', 'Einf B']] = valid_xs[['Cell line name', 'Compound B', 
               'Compound A', 'Max. conc. B',
       'Max. conc. A', 'IC50 B', 
       'H B', 'Einf B', 
       'IC50 A', 'H A', 'Einf A']]

# %% [markdown]
# Sanity check: let's see of valid_xs_perm is the permuted version of valid_xs

# %%
print(valid_xs_perm.head(5))
print(valid_xs.head(5))
# Out:
#     Cell line name  Compound A  Compound B  Max. conc. A  ...      Einf A  \
# 5               32           2          32           1.0  ...   58.538452
# 11               7           2          49           1.0  ...   34.658417
# 19              51          27          40           1.0  ...  100.000000
# 33              35           1           2          75.0  ...   73.495689
# 40              28          11          36           3.0  ...    0.764862
#
#       IC50 B        H B     Einf B
# 5   1.000008  10.000000  78.399574
# 11  1.000000   0.556940  54.700432
# 19  1.000000  10.000000  93.800095
# 33  1.000000   0.258988  17.701706
# 40  0.006467   0.244922   0.000000
#
# [5 rows x 11 columns]
#     Cell line name  Compound A  Compound B  Max. conc. A  ...     Einf A  \
# 5               32          32           2           3.0  ...  78.399574
# 11               7          49           2           1.0  ...  54.700432
# 19              51          40          27           1.0  ...  93.800095
# 33              35           2           1           1.0  ...  17.701706
# 40              28          36          11           3.0  ...   0.000000
#
#       IC50 B       H B      Einf B
# 5   0.099498  2.531000   58.538452
# 11  0.235409  1.182479   34.658417
# 19  1.000000  0.000000  100.000000
# 33  0.540880  4.851464   73.495689
# 40  3.000000  0.103996    0.764862
#
# [5 rows x 11 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Baseline model: mean and median

# %% [markdown]
#   Let's see how good it performs a model whose only information is the mean or the median of the train set.

# %%
mean = np.mean(y)
median = np.median(y)
print(f" Median = {median} \n Mean = {mean}")
# Out:
#  Median = 9.755132675170898
#  Mean = 12.747145652770996

# %% [markdown]
# We create our metrics

# %%
def r_mse(pred,y): return round(math.sqrt(((pred-y)**2).mean()), 6)
def m_rmse(m, xs, y): return r_mse(m.predict(xs), y)

# %%
error_mean = r_mse(mean, valid_y)
error_median = r_mse(median, valid_y)
print(f" Error Median = {error_median} \n Error Mean = {error_mean}")
# Out:
#  Error Median = 28.020177
#  Error Mean = 27.897856

# %% [markdown]
# However, we now know that the correct metric is going to be a weighted Pearson correlation coefficient, which takes into account the number of cell lines used per drug pair experiment. It will give 0 for uncorrelated data.
#
# What we want to measure is if the experimental and predicted synergy scores are correlated for every drug pair.

# %%
def weighted_pearson(df_dc_test, y_pred):
    
    
    """
    Computes the weighted Pearson correlation coefficient and a DataFrame of
    the individual Pearson coefficients of each combination
    
    INPUTS:
    df_dc_test: dataset used for inference. We only use the combination
                    id and the observed synergy.
    y_pred: predictions of the model"""

    y_obs = np.asarray(df_dc_test["Synergy score"])
    
    cl_count = Counter(df_dc_test["Combination ID"])

    id_list = list(cl_count.keys())

    rho_list = list()
    
    numerator = 0
    denominator = 0


    for ids in id_list:
        
        "We compute the appropiate mask, since combinations are not"
        "grouped in the dataset"
        condition = df_dc_test["Combination ID"] == ids
        
        pearson = np.corrcoef(y_pred[condition], y_obs[condition])
        "pearson is a correlation matrix, we want an off-diagonal term"
        rho_list.append(pearson[0,1])
        
        "Number of times each drug combination appears"
        rep =  np.sum(condition)
        
       
        "np.sqrt(rep-1) is the relative weight of the drug pair"
        
        numerator = numerator + np.sqrt(rep-1)*pearson[0,1]
        denominator = denominator + np.sqrt(rep-1)
        
    weighted_pear = numerator / denominator
    
    
    pear_weights_df = pd.DataFrame({"Combination ID" : id_list ,
                                    "n_cl" : list(cl_count.values()),
                                "Pearson coefficient" : rho_list })
    
    return weighted_pear, pear_weights_df

# %% [markdown]
# We make a function that accounts for possible values of nan's in the dataset and sets them to 0.

# %%
def nan_weighted_pearson(df_dc_test, y_pred):
    
    
    """
    Computes the weighted Pearson correlation coefficient and a DataFrame of
    the individual Pearson coefficients of each combination, 
    setting nan's to 0.
    
    INPUTS:
    df_dc_test: dataset used for inference. We only use the combination
                    id and the observed synergy.
    y_pred: predictions of the model"""

    y_obs = np.asarray(df_dc_test["Synergy score"])
    
    cl_count = Counter(df_dc_test["Combination ID"])

    id_list = list(cl_count.keys())

    rho_list = list()
    
    numerator = 0
    denominator = 0


    for ids in id_list:
        
        "We compute the appropiate mask, since combinations are not"
        "grouped in the dataset"
        condition = df_dc_test["Combination ID"] == ids
        
        pearson = np.corrcoef(y_pred[condition], y_obs[condition])
        "pearson is a correlation matrix, we want an off-diagonal term"
        if np.isnan(pearson[0,1]):
          rho_i = 0
        else: 
          rho_i = pearson[0,1]
        rho_list.append(rho_i)
        
        "Number of times each drug combination appears"
        rep =  np.sum(condition)
        
       
        "np.sqrt(rep-1) is the relative weight of the drug pair"
        
        numerator = numerator + np.sqrt(rep-1)*rho_i
        denominator = denominator + np.sqrt(rep-1)
        
    weighted_pear = numerator / denominator
    
    
    pear_weights_df = pd.DataFrame({"Combination ID" : id_list ,
                                    "n_cl" : list(cl_count.values()),
                                "Pearson coefficient" : rho_list })
    
    return weighted_pear, pear_weights_df

# %% [markdown]
# And one that only gives metric for fast training:

# %%
def wpc_score(df_dc_test, y_pred):
    
    
    """
    Computes the weighted Pearson correlation coefficient and a DataFrame of
    the individual Pearson coefficients of each combination, 
    setting nan's to 0.
    
    INPUTS:
    df_dc_test: dataset used for inference. We only use the combination
                    id and the observed synergy.
    y_pred: predictions of the model"""

    y_obs = np.asarray(df_dc_test["Synergy score"])
    
    cl_count = Counter(df_dc_test["Combination ID"])

    id_list = list(cl_count.keys())

    rho_list = list()
    
    numerator = 0
    denominator = 0


    for ids in id_list:
        
        "We compute the appropiate mask, since combinations are not"
        "grouped in the dataset"
        condition = df_dc_test["Combination ID"] == ids
        
        pearson = np.corrcoef(y_pred[condition], y_obs[condition])
        "pearson is a correlation matrix, we want an off-diagonal term"
        if np.isnan(pearson[0,1]):
          rho_i = 0
        else: 
          rho_i = pearson[0,1]
        
        
        "Number of times each drug combination appears"
        rep =  np.sum(condition)
        
       
        "np.sqrt(rep-1) is the relative weight of the drug pair"
        
        numerator = numerator + np.sqrt(rep-1)*rho_i
        denominator = denominator + np.sqrt(rep-1)
        
    weighted_pear = numerator / denominator
    
    
    
    return weighted_pear

# %%
test_df = df_drug_comb.iloc[test_idx]
test_df
# Out:
#      Cell line name  Compound A     Compound B  Max. conc. A  ...        H B  \
# 5           HT-1197        FGFR            AKT           3.0  ...   2.531000
# 11           BT-549    PIK3CA_4            AKT           1.0  ...   1.182479
# 19          MFM-223     MAP2K_1           ERBB           1.0  ...   0.000000
# 33         Hs-578-T         AKT         ADAM17           1.0  ...   4.851464
# 40          HCC1954         IAP         BCL2L1           3.0  ...   0.103996
# ...             ...         ...            ...           ...  ...        ...
# 5256        MFM-223         AKT         ADAM17           1.0  ...   0.000000
# 5260        HCC1806      MTOR_1           FASN           1.0  ...  10.000000
# 5261            RKO         TKI        MAP2K_1           3.0  ...   0.969392
# 5262        CAL-120  TNKS_PARP6  PIK3CB_PIK3CD           1.0  ...  10.000000
# 5265      NCI-H1975      TOP2_2            IAP           3.0  ...   0.493178
#
#           Einf B  Synergy score            Combination ID
# 5      58.538453      -3.891046                  AKT.FGFR
# 11     34.658416      12.835160              AKT.PIK3CA_4
# 19    100.000000     -18.621690              ERBB.MAP2K_1
# 33     73.495692      11.609180                ADAM17.AKT
# 40      0.764862      56.365480                BCL2L1.IAP
# ...          ...            ...                       ...
# 5256  100.000000      38.850700                ADAM17.AKT
# 5260   75.080116     -50.139620               FASN.MTOR_1
# 5261    0.000000      11.056320               MAP2K_1.TKI
# 5262   70.299621      14.689200  PIK3CB_PIK3CD.TNKS_PARP6
# 5265   71.768277      46.534060                IAP.TOP2_2
#
# [1089 rows x 13 columns]

# %% [markdown]
# **Sanity check:** we try the metric by predicting values around the mean of the synergy score of the train split. As this values are random, statistically they will be uncorrelated with the experimental values. We should obtain a weighted Pearson score close to 0.

# %%
n_exp = len(test_idx)
y_pred = np.ones(n_exp)* mean  + np.random.random(n_exp)*1000
weighted_pear, pear_weights_df = weighted_pearson(test_df, y_pred)
print("Weighted Pearson: ", weighted_pear)
# Out:
# Weighted Pearson:  0.02658564225109192

# %% [markdown]
# It's very small and oscillates around 0.

# %% [markdown]
# # Decision Trees

# %%
# Now that we have preprocessed our dataset, we build the tree



Tree = DecisionTreeRegressor(max_leaf_nodes=4)
Tree.fit(xs, y);

# %%
draw_tree(Tree, xs, size=10, leaves_parallel=True, precision=2)

# %%
samp_idx = np.random.permutation(len(y))[:500]
dtreeviz(Tree, xs.iloc[samp_idx], y.iloc[samp_idx], xs.columns, dep_var,
        fontname='DejaVu Sans', scale=1.6, label_fontsize=10,
        orientation='LR')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   "X does not have valid feature names, but"

# %% [markdown]
# Let's now have the decision tree algorithm build a bigger tree. Here, we are not passing in any stopping criteria such as max_leaf_nodes:

# %%
m = DecisionTreeRegressor()
m.fit(xs, y);

# %%
# In the training set
m_rmse(m, xs, y)
# Out:
# 0.0

# %% [markdown]
# This just means that the model fits well in the training dataset, but we have to check how well it generalizes over unseen data:

# %%
m_rmse(m, valid_xs, valid_y)
# Out:
# 36.81299

# %% [markdown]
# Now we will check for overfitting:

# %%
m.get_n_leaves(), len(xs)
# Out:
# (1795, 1795)

# %% [markdown]
# We see that it has as many leafs as datapoints, let's see what happens if we restrict the model.

# %%
m = DecisionTreeRegressor(min_samples_leaf=25)
m.fit(to.train.xs, to.train.y)
m_rmse(m, xs, y), m_rmse(m, valid_xs, valid_y)
# Out:
# (23.997595, 28.145969)

# %%
m.get_n_leaves()
# Out:
# 55

# %% [markdown]
# **The RMSE is almost the same as the baseline model. That's not good, let's try some hyperparameter tuning.**

# %%
leafs = np.arange(500)+1
error_list = list()
for n_leafs in leafs:
  m = DecisionTreeRegressor(min_samples_leaf=n_leafs)
  m.fit(to.train.xs, to.train.y)
  error_list.append( m_rmse(m, valid_xs, valid_y) )

# %%
error_list = np.asarray(error_list)
best_error = min(error_list)
best_leaf = leafs[error_list== min(error_list)][0]
print(f"Best number of leafs = {best_leaf} \n Error = {best_error}")
# Out:
# Best number of leafs = 152
#  Error = 27.38495

# %% [markdown]
# Let's check our metric

# %%
m = DecisionTreeRegressor(min_samples_leaf = best_leaf)
m.fit(to.train.xs, to.train.y)
y_pred = m.predict(valid_xs)
print(test_df.shape)
weighted_pear, pear_weights_df = weighted_pearson(test_df, y_pred)
print("Weighted Pearson: ", weighted_pear)
print(pear_weights_df)
# Out:
# (1089, 13)
# Weighted Pearson:  nan
#       Combination ID  n_cl  Pearson coefficient
# 0          EGFR.FGFR     6             0.391300
# 1        FASN.MTOR_1     7            -0.124258
# 2         IAP.IGFR_3     3            -0.863058
# 3        FGFR.MTOR_3     5             0.560462
# 4         IAP.PIK3CB    10             0.462958
# ..               ...   ...                  ...
# 162   Cisplatin.FGFR     3            -0.974069
# 163      HSP90.PIK3C     3             0.903799
# 164  ATM.Gemcitabine     3             0.279843
# 165     ATR_4.HDAC_4     3             0.982505
# 166   BCL2.CSNK2A1_2     6            -0.523300
#
# [167 rows x 3 columns]
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2691: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2692: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]

# %% [markdown]
# For some drug combination we obtain NaN's. My hypothesis is that for some drug pairs the predicted value is the same for all cell lines.

# %%
check_nan = pear_weights_df["Pearson coefficient"].isnull()
combination_index = np.arange(pear_weights_df.shape[0], dtype = int)
nan_combinations = pear_weights_df.iloc[combination_index[check_nan]]
nan_combinations
# Out:
#         Combination ID  n_cl  Pearson coefficient
# 54       ALK.CSNK2A1_2     6                  NaN
# 96   MTOR_1.TNKS_PARP6     7                  NaN
# 133    Cisplatin.PIK3C     3                  NaN
# 138      AKT.Cisplatin     3                  NaN
# 148    AKT.Chloroquine     5                  NaN
# 157     MTOR_1.SLC16A4     7                  NaN

# %% [markdown]
# These are the drug combinations that have a NaN Pearson correlation. We pick the first one and check for the predicted values.

# %%
nan_mask = test_df["Combination ID"] == "ALK.CSNK2A1_2"
ALK_CSNK2A1_2_df = test_df[nan_mask]
ALK_CSNK2A1_2_df
# Out:
#      Cell line name Compound A Compound B  Max. conc. A  ...       H B  \
# 217       NCI-H1563  CSNK2A1_2        ALK          0.03  ...  1.831949
# 272        NCI-H522  CSNK2A1_2        ALK          0.03  ...  1.652920
# 1386      NCI-H2085  CSNK2A1_2        ALK          0.03  ...  1.161107
# 1633          SW900  CSNK2A1_2        ALK          0.01  ...  0.685584
# 3290      NCI-H2291  CSNK2A1_2        ALK          0.01  ...  0.796128
# 3331       NCI-H838  CSNK2A1_2        ALK          0.10  ...  1.619777
#
#         Einf B  Synergy score  Combination ID
# 217   1.578234       5.147264   ALK.CSNK2A1_2
# 272   0.000000     -15.121200   ALK.CSNK2A1_2
# 1386  0.000000       9.019851   ALK.CSNK2A1_2
# 1633  0.000000      15.030920   ALK.CSNK2A1_2
# 3290  0.000000      16.914830   ALK.CSNK2A1_2
# 3331  0.000000      16.545240   ALK.CSNK2A1_2
#
# [6 rows x 13 columns]

# %%
y_pred_ALK_CSNK2A1_2 = y_pred[nan_mask]
y_pred_ALK_CSNK2A1_2
# Out:
# array([21.05977048, 21.05977048, 21.05977048, 21.05977048, 21.05977048, 21.05977048])

# %% [markdown]
# Just as I imagined. We are predicting the same values over and over. That's why our metric fails.

# %%
plt.plot(y_pred_ALK_CSNK2A1_2 , ALK_CSNK2A1_2_df["Synergy score"] , "bo")
plt.ylabel("Experimental Synergy", fontsize = 15)
plt.xlabel("Predicted Synergy", fontsize = 15)
plt.savefig("predicted_experimental_synergy_decision_tree_nan.eps", format = 'eps', dpi=300)

# %% [markdown]
# Now with our metric function that takes nan's into account:

# %%
weighted_pear, pear_weights_df = nan_weighted_pearson(test_df, y_pred)
print("Weighted Pearson: ", weighted_pear)
print(pear_weights_df)
# Out:
# Weighted Pearson:  0.11147801629765684
#       Combination ID  n_cl  Pearson coefficient
# 0          EGFR.FGFR     6             0.391300
# 1        FASN.MTOR_1     7            -0.124258
# 2         IAP.IGFR_3     3            -0.863058
# 3        FGFR.MTOR_3     5             0.560462
# 4         IAP.PIK3CB    10             0.462958
# ..               ...   ...                  ...
# 162   Cisplatin.FGFR     3            -0.974069
# 163      HSP90.PIK3C     3             0.903799
# 164  ATM.Gemcitabine     3             0.279843
# 165     ATR_4.HDAC_4     3             0.982505
# 166   BCL2.CSNK2A1_2     6            -0.523300
#
# [167 rows x 3 columns]
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2691: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2692: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]

# %% [markdown]
# Just to make sure we check for the previous rows of pear_weights_df where there were nan's.

# %%
nan_combinations = pear_weights_df.iloc[combination_index[check_nan]]
nan_combinations
# Out:
#         Combination ID  n_cl  Pearson coefficient
# 54       ALK.CSNK2A1_2     6                  0.0
# 96   MTOR_1.TNKS_PARP6     7                  0.0
# 133    Cisplatin.PIK3C     3                  0.0
# 138      AKT.Cisplatin     3                  0.0
# 148    AKT.Chloroquine     5                  0.0
# 157     MTOR_1.SLC16A4     7                  0.0

# %% [markdown]
# The function works.

# %% [markdown]
# # Random Forest

# %%
def rf(xs, y, n_estimators=100, max_samples=300,
       max_features=0.5, min_samples_leaf=5, **kwargs):
    return RandomForestRegressor(n_jobs=-1, n_estimators=n_estimators,
        max_samples=max_samples, max_features=max_features,
        min_samples_leaf=min_samples_leaf, random_state = 42 ,oob_score=True).fit(xs, y)

# %%
m = rf(xs, y);
m_rmse(m, xs, y), m_rmse(m, valid_xs, valid_y)
# Out:
# (24.374761, 26.497797)

# %% [markdown]
# A little better than the Tree regressor, but not that great.

# %%
y_pred = m.predict(valid_xs)
weighted_pear, pear_weights_df = weighted_pearson(test_df, y_pred)
print("Weighted Pearson: ", weighted_pear)
print(pear_weights_df)
# Out:
# Weighted Pearson:  0.16706360356491573
#       Combination ID  n_cl  Pearson coefficient
# 0          EGFR.FGFR     6             0.429530
# 1        FASN.MTOR_1     7            -0.013100
# 2         IAP.IGFR_3     3             0.884104
# 3        FGFR.MTOR_3     5             0.914940
# 4         IAP.PIK3CB    10             0.398945
# ..               ...   ...                  ...
# 162   Cisplatin.FGFR     3            -0.755894
# 163      HSP90.PIK3C     3             0.304881
# 164  ATM.Gemcitabine     3            -0.278453
# 165     ATR_4.HDAC_4     3             0.999990
# 166   BCL2.CSNK2A1_2     6            -0.554555
#
# [167 rows x 3 columns]

# %% [markdown]
# We see that Random Forest gives better prediction than Decision Trees.
#
# Let's try to obtain meaningful info. For example, let's order drug combinations from highest to lowest correlation

# %%
ordered_df = pear_weights_df.sort_values(by = "Pearson coefficient",
                                         ascending = False)
print(ordered_df)
# Out:
#         Combination ID  n_cl  Pearson coefficient
# 165       ATR_4.HDAC_4     3             0.999990
# 31            FGFR.WNT     3             0.999920
# 8    Gemcitabine.PARP1     3             0.999857
# 156  EG5.PIK3CB_PIK3CD     3             0.998560
# 151        MAP2K_1.TKI     3             0.998325
# ..                 ...   ...                  ...
# 145  AKT_1.Chloroquine     5            -0.803913
# 148    AKT.Chloroquine     5            -0.807129
# 77            IAP.SN38     3            -0.971769
# 65      IGFR_4.MAP2K_1     3            -0.992857
# 85      IGFR_3.MAP2K_1     3            -0.996501
#
# [167 rows x 3 columns]

# %% [markdown]
# Now the most uncorrelated:

# %%
ordered_df["abs Pearson"] = np.abs(ordered_df["Pearson coefficient"])
ordered_df = ordered_df.sort_values(by ="abs Pearson",
                                         ascending = True)
ordered_df.head(10)
# Out:
#            Combination ID  n_cl  Pearson coefficient  abs Pearson
# 123          BCL2.MAP2K_1     3             0.005340     0.005340
# 122          FGFR.SLC16A4     6            -0.008699     0.008699
# 20        FGFR.TNKS_PARP6     7            -0.009324     0.009324
# 107  CarboTaxol.CSNK2A1_2     5            -0.009835     0.009835
# 1             FASN.MTOR_1     7            -0.013100     0.013100
# 137            AKT.HDAC_4     5            -0.015835     0.015835
# 117    ADAM17.BCL2_BCL2L1     7             0.022154     0.022154
# 13   ADAM17.PIK3CB_PIK3CD     8            -0.025216     0.025216
# 118             AKT.ATR_4    10            -0.027071     0.027071
# 149       Cisplatin.PARP1     3             0.028164     0.028164

# %%
sns.histplot(data = ordered_df["Pearson coefficient"], bins = 10)
plt.savefig("pearson_random_forest.eps", format = 'eps', dpi=300)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# Let's try to do a bit of hyperparameter tuning to check for the best hyperparameters for random forest.

# %%
def rf_training(xs, y, test_df, n_estimators=100, max_samples=300,
       max_features=0.5, min_samples_leaf=5, random_state = 42, **kwargs):
   m = RandomForestRegressor(n_jobs=-1, n_estimators=n_estimators,
        max_samples=max_samples, max_features=max_features,
        min_samples_leaf=min_samples_leaf,random_state = random_state , 
        oob_score=True)
   m.fit(xs, y)      
   y_pred = m.predict(valid_xs)
   weighted_pear = wpc_score(test_df, y_pred)
   return weighted_pear

# %% [markdown]
# Let's try our function and see if it reproduces previous results.

# %%
rf_training(xs, y, test_df)
# Out:
# 0.186327856782357

# %% [markdown]
# Close enough, the small difference can be explained by the fact that we didn't fix the random seed. Let's try some hyperparameter tuning.

# %% [markdown]
# # Tabular learner fastai
# As next model we will try a Tabular Learner from FastAI.
# First thing we have to do is normalize the data. We create another TabularPandas object:

# %%
procs_nn = [Categorify, FillMissing, Normalize]

to_nn = TabularPandas(df_nocomb, procs, cat, cont, y_names=dep_var, 
                      splits=splits)

# %% [markdown]
# Now we create our dataloader and check for the maximum and minimum of our data. This is useful as we will limit the output interval of our model

# %%
dls = to_nn.dataloaders(1024)
y = to_nn.train.y
y.min(),y.max()
# Out:
# (-178.6540985107422, 237.37640380859375)

# %% [markdown]
# We create our learner and look for an optimal learning rate with lr_find.

# %%
learn = tabular_learner(dls, y_range=(y.min(),y.max()), layers=[200,50, 20],
                        n_out=1, loss_func=F.mse_loss)
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.0010000000474974513)

# %% [markdown]
# Now we finetune our learner by a few epochs.

# %%
learn.fit_one_cycle(50, 1e-3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4117.541504</td>
#       <td>1458.527344</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4028.859131</td>
#       <td>1391.474365</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3947.213135</td>
#       <td>1327.601074</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3866.347656</td>
#       <td>1264.543091</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3689.180908</td>
#       <td>1205.392090</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3536.247314</td>
#       <td>1150.564453</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3368.241211</td>
#       <td>1101.905273</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>3209.256348</td>
#       <td>1057.416626</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3061.905518</td>
#       <td>1017.447632</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2943.799072</td>
#       <td>981.191895</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2835.016602</td>
#       <td>947.961792</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>2735.687988</td>
#       <td>916.820862</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>2637.875244</td>
#       <td>891.913513</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>2542.011719</td>
#       <td>870.113892</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>2459.287842</td>
#       <td>851.854675</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>2378.488525</td>
#       <td>835.453003</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>2303.067383</td>
#       <td>819.791138</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>2236.330078</td>
#       <td>804.899170</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>2173.187744</td>
#       <td>791.548706</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>2117.660645</td>
#       <td>780.775940</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2055.722900</td>
#       <td>772.528748</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>2000.897949</td>
#       <td>768.079773</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1950.218140</td>
#       <td>765.699646</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1902.858887</td>
#       <td>764.587708</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1861.331421</td>
#       <td>764.160034</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1820.628662</td>
#       <td>763.796753</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1778.303955</td>
#       <td>763.625610</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1742.350220</td>
#       <td>764.127502</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1707.649536</td>
#       <td>765.162354</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1676.274658</td>
#       <td>767.092773</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1642.064941</td>
#       <td>769.334106</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1608.245850</td>
#       <td>772.432434</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1577.738159</td>
#       <td>775.717407</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1548.277344</td>
#       <td>779.197449</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1519.872559</td>
#       <td>783.867188</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1492.310303</td>
#       <td>787.453918</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1466.580200</td>
#       <td>792.119446</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1441.598755</td>
#       <td>796.859497</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>1419.685913</td>
#       <td>801.774109</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1397.410156</td>
#       <td>808.022461</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1376.837646</td>
#       <td>814.164001</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>1356.423340</td>
#       <td>820.877686</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>1338.662231</td>
#       <td>828.393738</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>1318.217529</td>
#       <td>836.400513</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1299.216064</td>
#       <td>844.778625</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1283.620728</td>
#       <td>854.816101</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>1266.894653</td>
#       <td>866.399048</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>1251.654053</td>
#       <td>877.284546</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>1236.254272</td>
#       <td>887.564148</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>1223.613892</td>
#       <td>899.587708</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Lastly, we obtain our predictions and compute the WPC metric. Since the FastAI learner outputs a tensor, we have to Flatten it.

# %%
y_pred, targs = learn.get_preds()
y_pred = np.asarray(y_pred[:,0])
wpc_score(test_df, y_pred)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# 0.10968063703535985

# %%
weighted_pear, pear_weights_df = nan_weighted_pearson(test_df, y_pred)
print("Weighted Pearson: ", weighted_pear)
print(pear_weights_df)
# Out:
# Weighted Pearson:  0.10968063703535985
#       Combination ID  n_cl  Pearson coefficient
# 0          EGFR.FGFR     6             0.727809
# 1        FASN.MTOR_1     7             0.467770
# 2         IAP.IGFR_3     3            -0.944783
# 3        FGFR.MTOR_3     5             0.505273
# 4         IAP.PIK3CB    10             0.643841
# ..               ...   ...                  ...
# 162   Cisplatin.FGFR     3             0.678983
# 163      HSP90.PIK3C     3            -0.456856
# 164  ATM.Gemcitabine     3             0.647182
# 165     ATR_4.HDAC_4     3             0.328268
# 166   BCL2.CSNK2A1_2     6             0.292057
#
# [167 rows x 3 columns]

# %%
sns.histplot(data = pear_weights_df["Pearson coefficient"], bins = 10)
plt.savefig("pearson_tabular_learner.eps", format = 'eps', dpi=300)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Ensemble: Tabular Learner + Random Forest.
#
# We will average predictions between Tabular Learner and Random Forest to create a superior model.

# %%
"Random Forest"
m_rf = rf(xs, y);
"We take the two permutations and average"
y_pred_rf_1 = m_rf.predict(valid_xs)
y_pred_rf_2 = m_rf.predict(valid_xs_perm)
y_pred_rf = (y_pred_rf_1 + y_pred_rf_2)/2
wpc_score(test_df, y_pred_rf)
# Out:
# 0.18972436901425996

# %% [markdown]
# Let's see if performance increases when we use pearson correlation coefficient as metric and EarlyStopping and SaveModelCallback callbacks

# %%
"Tabular learner"
procs_nn = [Categorify, FillMissing, Normalize]
"For some reason the prediction improves when I don't normalize"
"so I will use procs instead of procs_nn"
to_nn = TabularPandas(df_nocomb, procs, cat, cont, y_names=dep_var, 
                      splits=splits)
dls = to_nn.dataloaders(1024)
y = to_nn.train.y
y.min(),y.max()

callbacks = [EarlyStoppingCallback(
    monitor='pearsonr',
    min_delta=0.01, patience=20), SaveModelCallback(monitor='pearsonr')]


learn = tabular_learner(dls, y_range=(y.min(),y.max()), layers=[30,20, 10],
                        n_out=1, loss_func=F.mse_loss, 
                        metrics = PearsonCorrCoef(), cbs = callbacks)
#learn.lr_find()

# %%
learn.fit(n_epoch = 300, lr = 0.001)
learn.recorder.plot_loss()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>pearsonr</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2439.272461</td>
#       <td>789.957275</td>
#       <td>0.066300</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1959.203003</td>
#       <td>778.613953</td>
#       <td>0.088198</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1676.245605</td>
#       <td>776.956726</td>
#       <td>0.104125</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1511.138916</td>
#       <td>786.300476</td>
#       <td>0.116763</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1379.007812</td>
#       <td>812.854065</td>
#       <td>0.125743</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1284.009644</td>
#       <td>846.582764</td>
#       <td>0.133607</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1205.768433</td>
#       <td>879.488464</td>
#       <td>0.141254</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1144.984009</td>
#       <td>893.779541</td>
#       <td>0.152445</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1090.873291</td>
#       <td>884.451416</td>
#       <td>0.167735</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1045.474976</td>
#       <td>853.820068</td>
#       <td>0.190987</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1008.590881</td>
#       <td>804.478516</td>
#       <td>0.227381</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>972.216431</td>
#       <td>755.882385</td>
#       <td>0.270996</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>934.347961</td>
#       <td>720.707275</td>
#       <td>0.307887</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>900.478210</td>
#       <td>697.458862</td>
#       <td>0.335816</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>867.741760</td>
#       <td>690.912903</td>
#       <td>0.344317</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td
td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>373.431671</td>
#       <td>701.953857</td>
#       <td>0.428565</td>
#       <td>00:00</td>
#     </t
# Better model found at epoch 0 with pearsonr value: 0.0662998365347577.
# Better model found at epoch 1 with pearsonr value: 0.08819803788881193.
# Better model found at epoch 2 with pearsonr value: 0.10412519576408763.
# Better model found at epoch 3 with pearsonr value: 0.11676289292316545.
# Better model found at epoch 4 with pearsonr value: 0.1257426500354565.
# Better model found at epoch 5 with pearsonr value: 0.13360743228384897.
# Better model found at epoch 6 with pearsonr value: 0.14125400765387935.
# Better model found at epoch 7 with pearsonr value: 0.15244548741405486.
# Better model found at epoch 8 with pearsonr value: 0.16773460609793533.
# Better model found at epoch 9 with pearsonr value: 0.19098659248511946.
# Better model found at epoch 10 with pearsonr value: 0.22738080417293932.
# Better model found at epoch 11 with pearsonr value: 0.2709957459663443.
# Better model found at epoch 12 with pearsonr value: 0.30788745693680614.
# Better model found at epoch 13 with pearsonr value: 0.33581596922106666.
# Better model found at epoch 14 with pearsonr value: 0.34431681970264494.
# Better model found at epoch 17 with pearsonr value: 0.3523762129813205.
# Better model found at epoch 18 with pearsonr value: 0.37103181578922634.
# Better model found at epoch 19 with pearsonr value: 0.3853617312845793.
# Better model found at epoch 20 with pearsonr value: 0.3928614846781192.
# Better model found at epoch 21 with pearsonr value: 0.3978363339083555.
# Better model found at epoch 22 with pearsonr value: 0.4038761266851793.
# Better model found at epoch 23 with pearsonr value: 0.4097912472439137.
# Better model found at epoch 24 with pearsonr value: 0.4159146062004635.
# Better model found at epoch 25 with pearsonr value: 0.42094493505677594.
# Better model found at epoch 26 with pearsonr value: 0.4256489763663196.
# Better model found at epoch 27 with pearsonr value: 0.4306609998927598.
# Better model found at epoch 28 with pearsonr value: 0.4315386597516419.
# Better model found at epoch 29 with pearsonr value: 0.4323420164962933.
# Better model found at epoch 30 with pearsonr value: 0.43441874284859855.
# Better model found at epoch 31 with pearsonr value: 0.4364958460986465.
# Better model found at epoch 32 with pearsonr value: 0.4371679102637157.
# Better model found at epoch 33 with pearsonr value: 0.43922578939272783.
# Better model found at epoch 38 with pearsonr value: 0.439840855741982.
# Better model found at epoch 39 with pearsonr value: 0.4398679449552873.
# Better model found at epoch 42 with pearsonr value: 0.441757653738723.
# Better model found at epoch 43 with pearsonr value: 0.44457806108778114.
# No improvement since epoch 42: early stopping

# %%
y_pred_nn_1, targs = learn.get_preds()
y_pred_nn_1 = np.asarray(y_pred_nn_1[:,0])


wpc_score(test_df, y_pred_nn_1)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# 0.22842532778420135

# %% [markdown]
# let's save this learner and try to optimise it more.

# %%
learn.save("/content/drive/MyDrive/archivos_tfm/tabular_model_commutative.pth")
# Out:
# Path('/content/drive/MyDrive/archivos_tfm/tabular_model_commutative.pth.pth')

# %%
"And load it"
learn.load("/content/drive/MyDrive/archivos_tfm/tabular_model_commutative.pth")
y_pred_nn_1, targs = learn.get_preds()
y_pred_nn_1 = np.asarray(y_pred_nn_1[:,0])


wpc_score(test_df, y_pred_nn_1)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# 0.22842532778420135

# %%
valid_xs_perm_nn = to_nn.valid.xs.copy()

valid_xs_perm_nn[[ 'Compound A', 'Compound B', 
                         'Max. conc. A',
                         'Max. conc. B', 
                         'IC50 A', 'H A', 
                         'Einf A', 'IC50 B', 
                         'H B', 'Einf B']] = to_nn.valid.xs[[ 'Compound B', 'Compound A', 
                         'Max. conc. B',
                         'Max. conc. A', 
                         'IC50 B', 'H B', 
                         'Einf B', 'IC50 A', 
                         'H A', 'Einf A']]
valid_xs_perm_nn
# Out:
#       Cell line name  Compound A  Compound B  Max. conc. A  ...      Einf A  \
# 5                 32           2          32           1.0  ...   58.538452
# 11                 7           2          49           1.0  ...   34.658417
# 19                51          27          40           1.0  ...  100.000000
# 33                35           1           2          75.0  ...   73.495689
# 40                28          11          36           3.0  ...    0.764862
# ...              ...         ...         ...           ...  ...         ...
# 5256              51           1           2          75.0  ...  100.000000
# 5260              26          31          43           1.0  ...   75.080116
# 5261              71          40          61           3.0  ...    0.000000
# 5262               9          51          64           1.0  ...   70.299622
# 5265              57          36          66           3.0  ...   71.768280
#
#         IC50 B        H B      Einf B
# 5     1.000008  10.000000   78.399574
# 11    1.000000   0.556940   54.700432
# 19    1.000000  10.000000   93.800095
# 33    1.000000   0.258988   17.701706
# 40    0.006467   0.244922    0.000000
# ...        ...        ...         ...
# 5256  0.226297   1.952148   17.477798
# 5260  0.068121   2.789950   27.901039
# 5261  1.000000   0.000000  100.000000
# 5262  0.009716   0.380575   38.365410
# 5265  0.464939   1.345137    2.480696
#
# [1089 rows x 11 columns]

# %%
y_pred_nn_2, targs = learn.predict(valid_xs_perm_nn)
y_pred_nn_2 = np.asarray(y_pred_nn_2[:,0])


wpc_score(test_df, y_pred_nn_2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-c0a6ce7a45a8> in <module>()
# ----> 1 y_pred_nn_2, targs = learn.predict(valid_xs_perm_nn)
#       2 y_pred_nn_2 = np.asarray(y_pred_nn_2[:,0])
#       3
#       4
#       5 wpc_score(test_df, y_pred_nn_2)
#
# /usr/local/lib/python3.7/dist-packages/fastai/tabular/learner.py in predict(self, row)
#      13     def predict(self, row):
#      14         "Predict on a Pandas Series"
# ---> 15         dl = self.dls.test_dl(row.to_frame().T)
#      16         dl.dataset.conts = dl.dataset.conts.astype(np.float32)
#      17         inp,preds,_,dec_preds = self.get_preds(dl=dl, with_input=True, with_decoded=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to_frame'

# %% [markdown]
# I have not been able to use valid_xs_perm_nn to predict something in the tabular learner.

# %% [markdown]
# All together:

# %%
y_pred_avg = (y_pred_rf + y_pred_nn_1 )/ 2
wpc_score(test_df, y_pred_avg)
# Out:
# 0.2558716549520519

# %% [markdown]
# # XGBOOST
#
# Out of curiosity, let's try XGBoost and ensemble it.

# %%
m_xgb = XGBRegressor(n_estimators=200, max_depth=7, eta=0.1, 
                     subsample=0.7, colsample_bytree=0.8, random_state = 42)
m_xgb.fit(xs, y)
y_pred_xgb_1 = m_xgb.predict(valid_xs)
y_pred_xgb_2 = m_xgb.predict(valid_xs_perm)
y_pred_xgb = (y_pred_xgb_1 + y_pred_xgb_2)
wpc_score(test_df, y_pred_xgb)
# Out:
# [12:07:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 0.26399471855306117

# %% [markdown]
# Now we ensemble RF, XGBoost and Tabular Learner.

# %%
y_pred_avg = (y_pred_rf + y_pred_nn_1 + y_pred_xgb)/ 3
wpc_score(test_df, y_pred_avg)
# Out:
# 0.2891897769098425

# %% [markdown]
# And only Random Forest and XGBoost

# %%
y_pred_avg = (y_pred_rf +  y_pred_xgb)/ 2
wpc_score(test_df, y_pred_avg)
# Out:
# 0.27029440238974517

# %% [markdown]
# # Support Vector Regressor

# %%
procs_nn = [Categorify, FillMissing, Normalize]

to_nn = TabularPandas(df_nocomb, procs_nn, cat, cont, y_names=dep_var, 
                      splits=splits)

# %%
m_SVR = SVR(kernel="linear")
m_SVR.fit(to_nn.train.xs, to_nn.train.y)
y_pred_SVR = m_SVR.predict(to_nn.valid.xs)

wpc_score(test_df, y_pred_SVR)
# Out:
# 0.14470302399770377

# %% [markdown]
# With both permutations

# %%
m_SVR = SVR(kernel="linear")
m_SVR.fit(xs, y)
y_pred_SVR_1 = m_SVR.predict(valid_xs)
y_pred_SVR_2 = m_SVR.predict(valid_xs_perm)
y_pred_SVR = (y_pred_SVR_1 + y_pred_SVR_2)/2

wpc_score(test_df, y_pred_SVR)
# Out:
# 0.14511698665160222

# %% [markdown]
# Now we ensemble the 4 of them:
# Random Forest + XGBoost + Neural Networks + SVM

# %%
y_pred_avg = (y_pred_rf + y_pred_nn_1 + y_pred_xgb + y_pred_SVR)/ 4
wpc_score(test_df, y_pred_avg)
# Out:
# 0.2941978824723345

# %% [markdown]
# ## Feature importance

# %%
def rf_feat_importance(m, df):
    return pd.DataFrame({'cols':df.columns, 'imp':m.feature_importances_}
                       ).sort_values('imp', ascending=False)

fi = rf_feat_importance(m_rf, xs)
fi[:10]
# Out:
#               cols       imp
# 0   Cell line name  0.122700
# 7           Einf A  0.119059
# 9              H B  0.117066
# 10          Einf B  0.109905
# 6              H A  0.107753
# 8           IC50 B  0.097234
# 5           IC50 A  0.094072
# 1       Compound A  0.081534
# 2       Compound B  0.081325
# 3     Max. conc. A  0.038421

# %%
def plot_fi(fi):
    return fi.plot('cols', 'imp', 'barh', figsize=(12,7), legend=False)

plot_fi(fi[:30]);

# %% [markdown]
# Here we don't have a lot of columns, so we don't have
# to erase any of them.

# %% [markdown]
# # Creating new features:
#
# We will try to do some feature engineering.
#
# First we are going to create features independent of the order of the drugs, since we would want our input to be commutative with respect to the drug.

# %%
df_nocomb.columns
# Out:
# Index(['Cell line name', 'Compound A', 'Compound B', 'Max. conc. A',
#        'Max. conc. B', 'IC50 A', 'H A', 'Einf A', 'IC50 B', 'H B', 'Einf B',
#        'Synergy score'],
#       dtype='object')

# %%
df_new_f = pd.DataFrame()
df_new_f[['Cell line name', 
          'Compound A', 'Compound B', 
          'Synergy score']] = df_nocomb[['Cell line name', 'Compound A', 
                     'Compound B', 'Synergy score']]
df_new_f["Av_max_conc"] =  (df_nocomb['Max. conc. A'] + df_nocomb['Max. conc. B']) / 2

df_new_f["abs_dif_max_conc"] =  np.abs(df_nocomb['Max. conc. A'] - df_nocomb['Max. conc. B'])

df_new_f["Av_IC50"] =  (df_nocomb['IC50 A'] + df_nocomb['IC50 B']) / 2

df_new_f["abs_dif_IC50"] =  np.abs(df_nocomb['IC50 A'] - df_nocomb['IC50 B'])

df_new_f["Av_H"] =  (df_nocomb['H A'] + df_nocomb['H B']) / 2

df_new_f["abs_dif_IC50"] =  np.abs(df_nocomb['H A'] + df_nocomb['H B'])

df_new_f["Av_Einf"] =  (df_nocomb['Einf A'] + df_nocomb['Einf B']) / 2

df_new_f["abs_dif_Einf"] =  np.abs(df_nocomb['Einf A'] + df_nocomb['Einf B'])

df_new_f
# Out:
#      Cell line name Compound A Compound B  Synergy score  ...  abs_dif_IC50  \
# 0           HCC1143       FGFR       EGFR      25.848650  ...      1.106136
# 1        MDA-MB-468      PIK3C      AKT_1      24.378630  ...     11.502789
# 2           MFM-223    MAP2K_1      ATR_4     -19.085140  ...     10.000000
# 3             BT-20     MTOR_1       FASN      20.951370  ...      1.660213
# 4             SW948     IGFR_3        IAP      40.200730  ...      1.233020
# ...             ...        ...        ...            ...  ...           ...
# 3470            RKO        JAK        IAP      -1.023761  ...     11.452473
# 3471      NCI-H1703   PIK3CA_3        IAP      12.894160  ...      2.845207
# 3472          SW948       PTK2    MAP2K_1      19.809670  ...      2.290002
# 3473     MDA-MB-453      PIK3C     ESR1_1      47.096230  ...      2.648087
# 3474          BT-20      PIK3C    MAP2K_3      42.359970  ...      1.813260
#
#           Av_H    Av_Einf  abs_dif_Einf
# 0     0.553068  82.493124    164.986248
# 1     5.751395  34.949883     69.899766
# 2     5.000000  87.549419    175.098838
# 3     0.830107   7.193071     14.386142
# 4     0.616510  49.210384     98.420767
# ...        ...        ...           ...
# 3470  5.726236  41.609320     83.218641
# 3471  1.422604   9.990222     19.980445
# 3472  1.145001   4.404042      8.808083
# 3473  1.324043  24.829379     49.658758
# 3474  0.906630  41.595543     83.191086
#
# [3475 rows x 11 columns]

# %%
cont,cat = cont_cat_split(df_new_f, 1, dep_var=dep_var)
to_new_f = TabularPandas(df_new_f, procs, cat, cont, y_names=dep_var, 
                         splits=splits)
xs_new_f, y_new_f = to_new_f.train.xs, to_new_f.train.y
valid_xs_new_f, valid_y_new_f = to_new_f.valid.xs, to_new_f.valid.y

# %%
"Random Forest"
m_rf = rf(xs_new_f, y_new_f, n_estimators=100, max_samples=500,
       max_features=0.7, min_samples_leaf=1 , random_state = 42);
y_pred_rf_new_f = m_rf.predict(valid_xs_new_f)
wpc_score(test_df, y_pred_rf_new_f)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-85-59244ea6e55c> in <module>()
#       3        max_features=0.7, min_samples_leaf=1 , random_state = 42);
#       4 y_pred_rf_new_f = m_rf.predict(valid_xs_new_f)
# ----> 5 wpc_score(test_df, y_pred_rf_new_f)
#
# <ipython-input-31-b1ddf88bb128> in wpc_score(df_dc_test, y_pred)
#      39
#      40         "Number of times each drug combination appears"
# ---> 41         rep =  np.sum(condition)
#      42
#      43
#
# <__array_function__ internals> in sum(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial, where)
#    2258
#    2259     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
# -> 2260                           initial=initial, where=where)
#    2261
#    2262
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      82                 return reduction(axis=axis, dtype=dtype, out=out, **passkwargs)
#      83             else:
# ---> 84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
#      86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10707         ):
#   10708             return NDFrame.sum(
# > 10709                 self, axis, skipna, level, numeric_only, min_count, **kwargs
#   10710             )
#   10711
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10445     ):
#   10446         return self._min_count_stat_function(
# > 10447             "sum", nanops.nansum, axis, skipna, level, numeric_only, min_count, **kwargs
#   10448         )
#   10449
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _min_count_stat_function(self, name, func, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10432             skipna=skipna,
#   10433             numeric_only=numeric_only,
# > 10434             min_count=min_count,
#   10435         )
#   10436
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4390                 )
#    4391             with np.errstate(all="ignore"):
# -> 4392                 return op(delegate, skipna=skipna, **kwds)
#    4393
#    4394     def _reindex_indexer(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      92             try:
#      93                 with np.errstate(invalid="ignore"):
# ---> 94                     return f(*args, **kwargs)
#      95             except ValueError as e:
#      96                 # we want to transform an object array
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/_ufunc_config.py in __exit__(self, *exc_info)
#     432             self.oldcall = seterrcall(self.call)
#     433
# --> 434     def __exit__(self, *exc_info):
#     435         seterr(**self.oldstate)
#     436         if self.call is not _Unspecified:
#
# KeyboardInterrupt:

# %%
"XGBoost"
m_xgb = XGBRegressor(n_estimators=200, max_depth=7, eta=0.1, 
                     subsample=0.7, colsample_bytree=0.8, random_state = 42)
m_xgb.fit(xs_new_f, y_new_f)
y_pred_xgb_new_f = m_xgb.predict(valid_xs_new_f)
wpc_score(test_df, y_pred_xgb_new_f)

# %% [markdown]
# It's doesn't improve predictions. We have to look in other direction.

# %% [markdown]
# # Visualizing Tabular Learner Model and extracting embedding dictionaries for Cell line, Compound A and Compound B.

# %% [markdown]
# First we try to see the model architecture

# %%
print(learn)
# Out:
# <fastai.tabular.learner.TabularLearner object at 0x7f40b84a2750>

# %%
def nested_children(m: torch.nn.Module):
    children = dict(m.named_children())
    output = {}
    if children == {}:
        # if module has no children; m is last child! :O
        return m
    else:
        # look for children from children... to the last child!
        for name, child in children.items():
            try:
                output[name] = nested_children(child)
            except TypeError:
                output[name] = nested_children(child)
    return output

model_layers = nested_children(learn)

# %%
model_layers
# Out:
# {'bn_cont': BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  'emb_drop': Dropout(p=0.0, inplace=False),
#  'embeds': {'0': Embedding(86, 19),
#   '1': Embedding(70, 17),
#   '2': Embedding(70, 17)},
#  'layers': {'0': {'0': Linear(in_features=61, out_features=30, bias=False),
#    '1': ReLU(inplace=True),
#    '2': BatchNorm1d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)},
#   '1': {'0': Linear(in_features=30, out_features=20, bias=False),
#    '1': ReLU(inplace=True),
#    '2': BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)},
#   '2': {'0': Linear(in_features=20, out_features=10, bias=False),
#    '1': ReLU(inplace=True),
#    '2': BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)},
#   '3': {'0': Linear(in_features=10, out_features=1, bias=True)},
#   '4': SigmoidRange(low=-178.6540985107422, high=237.37640380859375)}}

# %%
named_layers = dict(learn.named_modules())
print(named_layers)
# Out:
# {'': TabularModel(
#   (embeds): ModuleList(
#     (0): Embedding(86, 19)
#     (1): Embedding(70, 17)
#     (2): Embedding(70, 17)
#   )
#   (emb_drop): Dropout(p=0.0, inplace=False)
#   (bn_cont): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): LinBnDrop(
#       (0): Linear(in_features=61, out_features=30, bias=False)
#       (1): ReLU(inplace=True)
#       (2): BatchNorm1d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): LinBnDrop(
#       (0): Linear(in_features=30, out_features=20, bias=False)
#       (1): ReLU(inplace=True)
#       (2): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): LinBnDrop(
#       (0): Linear(in_features=20, out_features=10, bias=False)
#       (1): ReLU(inplace=True)
#       (2): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): LinBnDrop(
#       (0): Linear(in_features=10, out_features=1, bias=True)
#     )
#     (4): SigmoidRange(low=-178.6540985107422, high=237.37640380859375)
#   )
# ), 'embeds': ModuleList(
#   (0): Embedding(86, 19)
#   (1): Embedding(70, 17)
#   (2): Embedding(70, 17)
# ), 'embeds.0': Embedding(86, 19), 'embeds.1': Embedding(70, 17), 'embeds.2': Embedding(70, 17), 'emb_drop': Dropout(p=0.0, inplace=False), 'bn_cont': BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'layers': Sequential(
#   (0): LinBnDrop(
#     (0): Linear(in_features=61, out_features=30, bias=False)
#     (1): ReLU(inplace=True)
#     (2): BatchNorm1d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (1): LinBnDrop(
#     (0): Linear(in_features=30, out_features=20, bias=False)
#     (1): ReLU(inplace=True)
#     (2): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (2): LinBnDrop(
#     (0): Linear(in_features=20, out_features=10, bias=False)
#     (1): ReLU(inplace=True)
#     (2): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (3): LinBnDrop(
#     (0): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (4): SigmoidRange(low=-178.6540985107422, high=237.37640380859375)
# ), 'layers.0': LinBnDrop(
#   (0): Linear(in_features=61, out_features=30, bias=False)
#   (1): ReLU(inplace=True)
#   (2): BatchNorm1d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ), 'layers.0.0': Linear(in_features=61, out_features=30, bias=False), 'layers.0.1': ReLU(inplace=True), 'layers.0.2': BatchNorm1d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'layers.1': LinBnDrop(
#   (0): Linear(in_features=30, out_features=20, bias=False)
#   (1): ReLU(inplace=True)
#   (2): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ), 'layers.1.0': Linear(in_features=30, out_features=20, bias=False), 'layers.1.2': BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'layers.2': LinBnDrop(
#   (0): Linear(in_features=20, out_features=10, bias=False)
#   (1): ReLU(inplace=True)
#   (2): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ), 'layers.2.0': Linear(in_features=20, out_features=10, bias=False), 'layers.2.2': BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), 'layers.3': LinBnDrop(
#   (0): Linear(in_features=10, out_features=1, bias=True)
# ), 'layers.3.0': Linear(in_features=10, out_features=1, bias=True), 'layers.4': SigmoidRange(low=-178.6540985107422, high=237.37640380859375)}

# %%
valid_xs.shape
# Out:
# (1089, 11)

# %% [markdown]
# Now we extract the embedding dictionary

# %%
embedding = learn.embeds
print(embedding.named_modules)
# Out:
# <bound method Module.named_modules of ModuleList(
#   (0): Embedding(86, 19)
#   (1): Embedding(70, 17)
#   (2): Embedding(70, 17)
# )>

# %%
print("Number of cell lines: " , len(xs["Cell line name"].unique()))
print("Number of Drugs A: " , len(xs["Compound A"].unique()))
print("Number of Drugs B: " , len(xs["Compound B"].unique()))
# Out:
# Number of cell lines:  84
# Number of Drugs A:  69
# Number of Drugs B:  69

# %%
print(learn.model)
# Out:
# TabularModel(
#   (embeds): ModuleList(
#     (0): Embedding(86, 19)
#     (1): Embedding(70, 17)
#     (2): Embedding(70, 17)
#   )
#   (emb_drop): Dropout(p=0.0, inplace=False)
#   (bn_cont): BatchNorm1d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): LinBnDrop(
#       (0): Linear(in_features=61, out_features=30, bias=False)
#       (1): ReLU(inplace=True)
#       (2): BatchNorm1d(30, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): LinBnDrop(
#       (0): Linear(in_features=30, out_features=20, bias=False)
#       (1): ReLU(inplace=True)
#       (2): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): LinBnDrop(
#       (0): Linear(in_features=20, out_features=10, bias=False)
#       (1): ReLU(inplace=True)
#       (2): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): LinBnDrop(
#       (0): Linear(in_features=10, out_features=1, bias=True)
#     )
#     (4): SigmoidRange(low=-178.6540985107422, high=237.37640380859375)
#   )
# )

# %%
summary(learn.model, 11)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-7280f0dbd15c> in <module>()
# ----> 1 summary(learn.model, 11)
#
# /usr/local/lib/python3.7/dist-packages/torchsummary/torchsummary.py in summary(model, input_size, batch_size, device)
#      58
#      59     # batch_size of 2 for batchnorm
# ---> 60     x = [torch.rand(2, *in_size).type(dtype) for in_size in input_size]
#      61     # print(type(x[0]))
#      62
#
# TypeError: 'int' object is not iterable

# %%
embedding_0 = embedding[0]

# %%
input = torch.LongTensor([0])
embedding_0(input)
# Out:
# tensor([[-0.0076,  0.0123, -0.0196,  0.0108,  0.0075, -0.0086,  0.0070, -0.0084, -0.0026,  0.0053,  0.0023,  0.0088,  0.0039, -0.0115, -0.0034,  0.0109,  0.0091,  0.0008, -0.0063]],
#        grad_fn=<EmbeddingBackward0>)

# %%
valid_xs
# Out:
#       Cell line name  Compound A  Compound B  Max. conc. A  ...      Einf A  \
# 5                 32          32           2           3.0  ...   78.399574
# 11                 7          49           2           1.0  ...   54.700432
# 19                51          40          27           1.0  ...   93.800095
# 33                35           2           1           1.0  ...   17.701706
# 40                28          36          11           3.0  ...    0.000000
# ...              ...         ...         ...           ...  ...         ...
# 5256              51           2           1           1.0  ...   17.477798
# 5260              26          43          31           1.0  ...   27.901039
# 5261              71          61          40           3.0  ...  100.000000
# 5262               9          64          51           1.0  ...   38.365410
# 5265              57          66          36           3.0  ...    2.480696
#
#         IC50 B        H B      Einf B
# 5     0.099498   2.531000   58.538452
# 11    0.235409   1.182479   34.658417
# 19    1.000000   0.000000  100.000000
# 33    0.540880   4.851464   73.495689
# 40    3.000000   0.103996    0.764862
# ...        ...        ...         ...
# 5256  1.000000   0.000000  100.000000
# 5260  0.051205  10.000000   75.080116
# 5261  3.000000   0.969392    0.000000
# 5262  0.249083  10.000000   70.299622
# 5265  0.030254   0.493178   71.768280
#
# [1089 rows x 11 columns]

# %% [markdown]
# Vamos a obtener los diccionarios de las cell lines,  compound A y compound B

# %%
cl_cat_to_int = dict(zip(test_df["Cell line name"], valid_xs["Cell line name"]))
cl_embedding_dict = dict()
for i, cat in enumerate(cl_cat_to_int):
  cl_embedding_dict[(cat)] = embedding_0(torch.LongTensor([i])).detach().numpy()

# %%
cl_embedding_dict
# Out:
# {'22RV1': array([[-0.00897543,  0.02598321,  0.02002143, -0.00573113,  0.00226387,  0.02977065, -0.01245474,  0.00524208,  0.05333259, -0.01239858,  0.01318895,  0.0021014 ,  0.02188591,  0.01021426,
#           0.02383813,  0.00319444, -0.00712638,  0.04447477,  0.02945668]], dtype=float32),
#  '647-V': array([[-0.00447433,  0.01506898,  0.00816659, -0.03942322, -0.00502857, -0.01771179,  0.04537631, -0.02959894,  0.03722197, -0.03224654,  0.03485535,  0.01575203, -0.00748616,  0.03041947,
#          -0.00337443, -0.0128513 ,  0.04984659,  0.02184376, -0.00169032]], dtype=float32),
#  'A549': array([[-0.03759567, -0.00413775, -0.02164523, -0.00979365,  0.03212807,  0.05098707,  0.01294662,  0.00377404,  0.05147869, -0.03898619,  0.0135082 ,  0.00107821, -0.02103001,  0.00875649,
#           0.01674271, -0.00714688,  0.01094464,  0.02514663, -0.05880581]], dtype=float32),
#  'UACC-812': array([[ 0.01506924,  0.07498387, -0.00017506, -0.01616902,  0.07656708,  0.00233038,  0.02941051,  0.02895367,  0.04153742,  0.00913436, -0.05502865, -0.00316245, -0.03566134, -0.03964876,
#           0.01544076,  0.00649831, -0.01310699,  0.01890433, -0.03219441]], dtype=float32),
#  'UM-UC-3': array([[ 0.03419027, -0.05895489,  0.02847579,  0.00532343,  0.00857575, -0.02018411, -0.01333656,  0.04452023, -0.05487758, -0.01696777, -0.02581054, -0.00959797, -0.00093895, -0.03071242,
#          -0.01313508, -0.03455507,  0.01933818, -0.00815928,  0.00312157]], dtype=float32),
#  'VCaP': array([[-0.02736409, -0.04600978, -0.01446658, -0.03597746, -0.02323231, -0.01005052,  0.05116387, -0.00330421, -0.03831787,  0.00022647, -0.00109669,  0.04174095, -0.0206311 ,  0.00859503,
#          -0.04956041,  0.0133956 ,  0.0143202 , -0.00425663, -0.00156061]], dtype=float32),
#  'VM-CUB-1': array([[ 0.00344423, -0.02529898,  0.02959411, -0.0467695 ,  0.04657199,  0.01086372,  0.01521624,  0.0228596 , -0.04456493, -0.01469959, -0.03128822,  0.01411757, -0.04544629, -0.04644341,
#          -0.02758328, -0.00874718, -0.00239818,  0.04559672, -0.04570889]], dtype=float32)}

# %%
embedding_1 = embedding[1]
Compound_A_cat_to_int = dict(zip(test_df["Compound A"], valid_xs["Compound A"]))
Compound_A_embedding_dict = dict()
for i, cat in enumerate(Compound_A_cat_to_int):
  Compound_A_embedding_dict[(cat)] = embedding_1(torch.LongTensor([i])).detach().numpy()

# %%
Compound_A_embedding_dict
# Out:
# {'AKT': array([[-0.02647507,  0.0174162 , -0.03829989,  0.01048459,  0.00944627,  0.04841933, -0.01175978, -0.01094781, -0.00642714, -0.01783823, -0.02410454, -0.01503472,  0.01422337,  0.00787178,
#          -0.00838627,  0.02497517, -0.02419231]], dtype=float32),
#  'AKT_1': array([[ 0.0443061 ,  0.06800702, -0.01930578, -0.01044444,  0.02041329,  0.02715674, -0.01326696,  0.01072615,  0.00728724,  0.01418323, -0.02420046, -0.02371309,  0.02380822,  0.02331861,
#          -0.01922753, -0.02500356, -0.03179255]], dtype=float32),
#  'ALK_IGFR': array([[-0.03588109,  0.01404548, -0.00811012, -0.01418318, -0.01446435,  0.01049848, -0.01424283,  0.01092361,  0.00841047,  0.03578247,  0.01335141, -0.02546551, -0.01852539, -0.00143259,
#           0.03609972, -0.02396003, -0.02036897]], dtype=float32),
#  'ATR_4': array([[ 0.00737876, -0.06606667,  0.04147857, -0.01603118,  0.02519993,  0.01219589,  0.05071529, -0.01577407,  0.03170373, -0.03933052, -0.02720767,  0.03173883,  0.03025031, -0.05205555,
#          -0.05147682,  0.05634582,  0.04930083]], dtype=float32),
#  'BCL2L1': array([[-0.00449512, -0.0315969 ,  0.00757516, -0.01280761,  0.02735521,  0.01574668,  0.00704929,  0.01676964, -0.01302209, -0.01352701, -0.00334877,  0.05433083,  0.02655828, -0.00985176,
#          -0.02015943, -0.01295792,  0.04033635]], dtype=float32),
#  'TNFSF10': array([[ 0.02489845,  0.0416248 , -0.02896821, -0.0140765 , -0.0226882 ,  0.04261914,  0.00095447, -0.00262455,  0.04193736, -0.02361717, -0.03994561, -0.0382802 , -0.02350006,  0.05409732,
#          -0.01250499, -0.00456346, -0.02982181]], dtype=float32),
#  'TNKS_PARP6': array([[-0.02325424,  0.01131279, -0.0128988 ,  0.00664329,  0.04645868,  0.01766309,  0.00186875, -0.00714968,  0.03067942, -0.01733005,  0.0470112 , -0.01094889,  0.00639251,  0.0046968 ,
#           0.05810123, -0.0006247 ,  0.03503798]], dtype=float32),
#  'TOP2': array([[-0.00629085,  0.0324984 , -0.02672866, -0.02564912,  0.00702175, -0.0332977 , -0.00934278, -0.02959858, -0.00954007,  0.03591361, -0.01416312, -0.05358995,  0.05098276,  0.02808508,
#           0.00439678, -0.01359184, -0.02515672]], dtype=float32),
#  'TOP2_2': array([[ 0.00705216, -0.05450232,  0.04738657, -0.05726543, -0.01309214,  0.00669646,  0.00189738, -0.00465635,  0.02307288,  0.00422415,  0.00404802, -0.00658881, -0.08004551, -0.00338215,
#           0.02403473, -0.01443647, -0.04121291]], dtype=float32),
#  'Topotecan': array([[-0.00616951,  0.00067365,  0.02848073,  0.02439035, -0.01784859, -0.05206151,  0.03324543, -0.0110782 ,  0.04417629,  0.00270453, -0.02678383,  0.05776496,  0.01497307, -0.06651919,
#          -0.01756621,  0.01326958,  0.03116544]], dtype=float32),
#  'Vinorelbine': array([[ 0.01042804, -0.05396513, -0.00403925,  0.04398303, -0.03303774,  0.02277893,  0.03095965,  0.03493597, -0.02629079, -0.04315737, -0.0161576 ,  0.02908539, -0.03469921, -0.03937611,
#          -0.00586436,  0.01877635, -0.00553907]], dtype=float32),
#  'WNT': array([[-0.0087185 ,  0.01245061, -0.01480278,  0.04017996, -0.00439671, -0.00377045,  0.00478689, -0.00323103, -0.00753016, -0.00358416,  0.02363428, -0.02799518,  0.00131262, -0.01570302,
#          -0.05472941,  0.03735472,  0.01701775]], dtype=float32)}

# %%
embedding_2 = embedding[2]
Compound_B_cat_to_int = dict(zip(test_df["Compound B"], valid_xs["Compound B"]))
Compound_B_embedding_dict = dict()
for i, cat in enumerate(Compound_B_cat_to_int):
  Compound_B_embedding_dict[(cat)] = embedding_2(torch.LongTensor([i])).detach().numpy()
Compound_B_embedding_dict
# Out:
# {'ADAM17': array([[ 3.8339975e-05, -1.5452372e-02,  1.1323296e-02,  2.8272854e-02, -2.1546476e-03,  1.8089056e-02, -2.0200517e-02,  2.2246605e-02, -3.2967947e-02,  2.9574785e-02, -1.9102411e-02,
#          -1.4448717e-02,  2.8151255e-03, -2.9226093e-02, -4.9022166e-03,  3.3816640e-04,  2.0470250e-02]], dtype=float32),
#  'AKT': array([[-0.00553862, -0.00201186,  0.00043135,  0.00256823,  0.00166286, -0.01160177,  0.00896006,  0.00945446,  0.00409647,  0.00210936,  0.01505675, -0.00124546, -0.00962757,  0.01465866,
#           0.00081092,  0.00119134, -0.00242015]], dtype=float32),
#  'PIK3CB_PIK3CD': array([[ 0.00369247,  0.00356168,  0.02929169,  0.07718443,  0.00259601,  0.01167193, -0.01711365,  0.03792544, -0.02080536,  0.0024197 ,  0.04485944,  0.00457985, -0.03349108, -0.00121789,
#          -0.0162077 ,  0.01429142,  0.03108086]], dtype=float32),
#  'PIK3C_2': array([[ 0.03659317, -0.00632823,  0.01350106,  0.00468398,  0.02451998,  0.01452305,  0.01955432, -0.02134941,  0.02056319, -0.01527634, -0.00540734, -0.02899889,  0.02603168,  0.02958138,
#           0.04076136, -0.01420389, -0.00807861]], dtype=float32),
#  'PIM1': array([[-0.02353571, -0.03874342,  0.01940367,  0.05798925, -0.01933984,  0.01076507, -0.02681478, -0.02627838, -0.04853443,  0.04301261, -0.04299638,  0.03311796, -0.01621634,  0.03456301,
#           0.04624117,  0.02037333,  0.00378193]], dtype=float32)}

# %% [markdown]
# We are going to save those dictionaries for latter. We will use pickle

# %%
with open('/content/drive/MyDrive/archivos_tfm/cl_embedding_dict.pkl', 'wb') as f:
    pickle.dump(cl_embedding_dict, f)

with open('/content/drive/MyDrive/archivos_tfm/Compound_A_embedding_dict.pkl', 'wb') as f:
    pickle.dump(Compound_A_embedding_dict, f)

with open('/content/drive/MyDrive/archivos_tfm/Compound_B_embedding_dict.pkl', 'wb') as f:
    pickle.dump(Compound_B_embedding_dict, f)

# %% [markdown]
# Let's see if it works

# %%
with open('/content/drive/MyDrive/archivos_tfm/Compound_B_embedding_dict.pkl', 'rb') as f:
    loaded_dict = pickle.load(f)

loaded_dict
# Out:
# {'ADAM17': array([[ 3.8339975e-05, -1.5452372e-02,  1.1323296e-02,  2.8272854e-02, -2.1546476e-03,  1.8089056e-02, -2.0200517e-02,  2.2246605e-02, -3.2967947e-02,  2.9574785e-02, -1.9102411e-02,
#          -1.4448717e-02,  2.8151255e-03, -2.9226093e-02, -4.9022166e-03,  3.3816640e-04,  2.0470250e-02]], dtype=float32),
#  'AKT': array([[-0.00553862, -0.00201186,  0.00043135,  0.00256823,  0.00166286, -0.01160177,  0.00896006,  0.00945446,  0.00409647,  0.00210936,  0.01505675, -0.00124546, -0.00962757,  0.01465866,
#           0.00081092,  0.00119134, -0.00242015]], dtype=float32),
#  'AKT_1': array([[ 0.0352821 , -0.01259737,  0.03217355, -0.00444659,  0.01195889,  0.03102946, -0.04952654, -0.02742838,  0.0140539 , -0.00977929,  0.03246417,  0.00274946,  0.00753881, -0.00052312,
#          -0.01298804, -0.03982118,  0.023619  ]], dtype=float32),
#  'AKT_SGK': array([[ 0.01518066, -0.04462318, -0.0070426 ,  0.04669243, -0.03644916,  0.01789666,  0.01712859, -0.00196855, -0.04805664,  0.05580732,  0.05132208,  0.03283544, -0.02685606,  0.01911341,
#           0.02834904,  0.01208367, -0.00757031]], dtype=float32),
#  'ALK': array([[ 0.02961412, -0.00624373, -0.02168796,  0.0289596 , -0.05576079, -0.04965208,  0.04990087, -0.03122168, -0.0299448 ,  0.05935361,  0.03552028,  0.06044486, -0.02963252, -0.01393731,
#           0.05262209,  0.01383156, -0.038272  ]], dtype=float32),
#  'ESR1': array([[ 0.01851845,  0.0328097 ,  0.02274868,  0.02982038,  0.03756932,  0.07349912, -0.04660064,  0.06298038,  0.05502292, -0.04325747,  0.04445845, -0.01283752,  0.03202824, -0.0396271 ,
#          -0.05312167, -0.02040519,  0.00169784]], dtype=float32),
#  'ESR1_1': array([[ 0.02308163, -0.02657351, -0.04001999,  0.04710635, -0.05688949, -0.03774811,  0.04795793,  0.00966107, -0.04473604,  0.0426995 , -0.0317971 ,  0.01751337, -0.01852645,  0.01524043,
#           0.04121556,  0.00433389, -0.01111665]], dtype=float32),
#  'ESR1_3': array([[ 0.01372474,  0.01086805,  0.01350469, -0.04473938,  0.00938005,  0.00943773,  0.00101146,  0.02214409,  0.01912126, -0.02429509,  0.03145418,  0.02401267,  0.03773875, -0.03775128,
#          -0.02475547,  0.00998996, -0.0114756 ]], dtype=float32),
#  'FASN': array([[-0.00308987, -0.06320832, -0.03313368,  0.05131646, -0.02331945, -0.00876473,  0.04236146,  0.00472602, -0.06149542,  0.07819239, -0.0397056 ,  0.01051522, -0.02969433, -0.0144464 ,
#           0.01403067,  0.02684725, -0.01704142]], dtype=float32),
#  'FGFR': array([[ 0.08130433, -0.04705119, -0.03649836, -0.01495931, -0.01758333,  0.00383894,  0.00799469,  0.00141279,  0.00387348, -0.04133066, -0.00836001,  0.0133767 , -0.03842387,  0.05238308,
#           0.04278648, -0.03741158,  0.07201621]], dtype=float32),
#  'Gemcitabine': array([[-0.01879562,  0.00205472, -0.02272398, -0.0430431 , -0.02411474, -0.03119896,  0.05499069,  0.05291666,  0.02248607, -0.00988866, -0.01058614,  0.00440486, -0.04306124,  0.03507422,
#           0.03486733, -0.00536748, -0.0221828 ]], dtype=float32),
#  'HDAC_4': array([[ 0.01161856, -0.00407413,  0.00301008, -0.01121089,  0.00075311, -0.04394963,  0.01479252, -0.00024969,  0.03837609, -0.05072206,  0.01346724,  0.01575499, -0.01619076,  0.01776322,
#          -0.00637677, -0.00447358,  0.00918768]], dtype=float32),
#  'HSP90': array([[ 0.01139696, -0.0002787 , -0.04841895,  0.02990317, -0.03346107, -0.03702401,  0.01975811, -0.01182721, -0.02443209, -0.00103293, -0.03642191,  0.03638127,  0.02063217,  0.01896504,
#          -0.0125096 ,  0.0355846 , -0.05089385]], dtype=float32),
#  'IAP': array([[-0.01977788,  0.01709407,  0.01327705,  0.02818635, -0.01717328,  0.00407908, -0.03578564, -0.03880539, -0.02774917,  0.02824328,  0.04596518, -0.00738017, -0.02130262,  0.01468867,
#           0.03110125,  0.01324079,  0.0157828 ]], dtype=float32),
#  'IGFR_3': array([[ 0.05786665,  0.00133074, -0.02667681, -0.02820641, -0.06807365, -0.02628232,  0.05528046,  0.03976597, -0.02980587, -0.00659888, -0.01162328,  0.0258364 ,  0.01898644,  0.01738565,
#          -0.01922952,  0.03288861, -0.02628039]], dtype=float32),
#  'IGFR_4': array([[-2.03106031e-02,  2.14304030e-02,  6.25976026e-02,  6.60049915e-03,  2.53965296e-02, -2.97873318e-02, -3.39465290e-02,  2.18383241e-02,  9.68057429e-06, -1.33788493e-02,  6.04352839e-02,
#          -8.68525077e-03,  1.33830365e-02,  3.33330370e-02, -3.34042385e-02,  3.06157339e-02,  5.73320687e-03]], dtype=float32),
#  'JAK': array([[ 0.00172739, -0.01155686,  0.02918116,  0.00609122,  0.03423318, -0.00733525, -0.02686138,  0.02820846,  0.00930914,  0.01347953,  0.03173747, -0.00602051,  0.01089688,  0.0161588 ,
#          -0.00319365, -0.01419806, -0.0085395 ]], dtype=float32),
#  'MAP2K_1': array([[ 0.00646121, -0.00776907,  0.01651508, -0.05844654,  0.01327331,  0.01126946,  0.06728937, -0.02230153,  0.04127755, -0.05020824, -0.02835259, -0.05269866,  0.00936414,  0.01920428,
#          -0.02141336, -0.02804449, -0.00745915]], dtype=float32),
#  'MAP2K_3': array([[-0.02613344,  0.02208932, -0.05684842,  0.00480947,  0.01681837, -0.00367607,  0.03643381,  0.03799719,  0.00097553, -0.03218202, -0.02214716, -0.01303916, -0.00724287, -0.00814785,
#           0.02282432,  0.0177852 ,  0.01648578]], dtype=float32),
#  'MTOR_1': array([[-0.02427446, -0.04184831, -0.01109007, -0.02946977, -0.00300856, -0.01221054,  0.03897953, -0.01812197, -0.02200569, -0.00785338, -0.0315836 , -0.01560266, -0.04586821,  0.01487774,
#           0.00729849,  0.02092705,  0.02588614]], dtype=float32),
#  'PARP1': array([[ 0.00441039,  0.02824457, -0.01587656,  0.00713018, -0.02140278, -0.02728115,  0.03094632,  0.04691903, -0.04327885,  0.02731039,  0.01038867,  0.05060528,  0.04046773, -0.00255116,
#          -0.0039156 ,  0.02992943, -0.01458033]], dtype=float32),
#  'PIK3C': array([[-0.02170228, -0.04353954,  0.0333905 ,  0.07511678,  0.02487388,  0.03822343, -0.06035387,  0.01696223, -0.02715533,  0.00775169,  0.0385788 , -0.01337215, -0.03258476,  0.02887541,
#          -0.0327477 ,  0.03107424,  0.00603329]], dtype=float32),
#  'PIK3CB': array([[ 0.01636848, -0.01044387,  0.03474102, -0.04412828,  0.01603593,  0.03844116, -0.01845984, -0.01725671,  0.03900921, -0.02472639, -0.02278348,  0.00400036,  0.02387154, -0.00241739,
#           0.01460517, -0.03409018, -0.00010084]], dtype=float32),
#  'PIK3CB_PIK3CD': array([[ 0.00369247,  0.00356168,  0.02929169,  0.07718443,  0.00259601,  0.01167193, -0.01711365,  0.03792544, -0.02080536,  0.0024197 ,  0.04485944,  0.00457985, -0.03349108, -0.00121789,
#          -0.0162077 ,  0.01429142,  0.03108086]], dtype=float32),
#  'PIK3C_2': array([[ 0.03659317, -0.00632823,  0.01350106,  0.00468398,  0.02451998,  0.01452305,  0.01955432, -0.02134941,  0.02056319, -0.01527634, -0.00540734, -0.02899889,  0.02603168,  0.02958138,
#           0.04076136, -0.01420389, -0.00807861]], dtype=float32),
#  'PIM1': array([[-0.02353571, -0.03874342,  0.01940367,  0.05798925, -0.01933984,  0.01076507, -0.02681478, -0.02627838, -0.04853443,  0.04301261, -0.04299638,  0.03311796, -0.01621634,  0.03456301,
#           0.04624117,  0.02037333,  0.00378193]], dtype=float32)}

# %% [markdown]
# It is correct
