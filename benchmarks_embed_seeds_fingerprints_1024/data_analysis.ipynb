# %%
import os
import pandas as pd
import glob
import numpy as np

# %%
seed_42_results = glob.glob('*seed_42.csv')
for path in seed_42_results:
   print(path)
# Out:
# pytorch_tabular_seed_42.csv
# sklearn_EmbeddingTabTransformer_seed_42.csv
# sklearn_EmbeddingCategoryEmbedding_seed_42.csv
# sklearn_EmbeddingAutoInt_seed_42.csv
# sklearn_LabelEncoder_seed_42.csv
# sklearn_OneHotEncoder_seed_42.csv

# %%
pt_42 = pd.read_csv(seed_42_results[0])
pt_42
# Out:
#                Model  Train WPC  Test WPC    LB WPC
# 0  CategoryEmbedding   0.296765  0.145083  0.280448
# 1            AutoInt   0.265659  0.229706  0.215356
# 2     TabTransformer   0.428189  0.150685  0.201933

# %%
label_encoder = pd.read_csv('sklearn_LabelEncoder_seed_42.csv')
label_encoder
# Out:
#                           Model  Train WPC  Test WPC    LB WPC
# 0             Linear Regression   0.147879  0.176708  0.103295
# 1              Ridge Regression   0.148275  0.176575  0.103226
# 2              Lasso Regression   0.142890  0.141979  0.125237
# 3         ElasticNet Regression   0.144258  0.158381  0.135864
# 4     Bayesian Ridge Regression   0.137032  0.144986  0.136435
# 5   Stochastic Gradient Descent   0.007399  0.069191  0.083716
# 6                 Decision Tree   1.000000  0.085984  0.063233
# 7                 Random Forest   0.973706  0.165937  0.206660
# 8                   Extra Trees   1.000000  0.166769  0.124917
# 9                      AdaBoost   0.258693  0.212776  0.124835
# 10            Gradient Boosting   0.640863  0.257878  0.147784
# 11                 XGBRegressor   0.996274  0.229902  0.223124
# 12    Support Vector Regression   0.049672  0.121110  0.124128
# 13             Gaussian Process   1.000000 -0.042138  0.073724

# %%
label_encoder = pd.read_csv('sklearn_OneHotEncoder_seed_42.csv')
label_encoder
# Out:
#                           Model  Train WPC  Test WPC    LB WPC
# 0             Linear Regression   0.378501  0.263700  0.223972
# 1              Ridge Regression   0.377664  0.265107  0.230479
# 2              Lasso Regression   0.140746  0.146002  0.132558
# 3         ElasticNet Regression   0.141694  0.155188  0.126045
# 4     Bayesian Ridge Regression   0.158476  0.175198  0.131706
# 5   Stochastic Gradient Descent   0.004872  0.008010 -0.078770
# 6                 Decision Tree   1.000000  0.107737  0.142747
# 7                 Random Forest   0.973976  0.241385  0.261166
# 8                   Extra Trees   1.000000  0.196811  0.226113
# 9                      AdaBoost   0.259326  0.215128  0.142081
# 10            Gradient Boosting   0.647997  0.265205  0.203545
# 11                 XGBRegressor   0.977231  0.221908  0.233892
# 12    Support Vector Regression   0.213493  0.120743  0.136682
# 13             Gaussian Process   1.000000  0.087631  0.086913

# %%
category_embedding = pd.read_csv('sklearn_EmbeddingCategoryEmbedding_seed_42.csv')
category_embedding
# Out:
#                           Model  Train WPC  Test WPC    LB WPC
# 0             Linear Regression   0.329687  0.242464  0.199809
# 1              Ridge Regression   0.329454  0.239805  0.208230
# 2              Lasso Regression   0.260661  0.171881  0.246978
# 3         ElasticNet Regression   0.293256  0.197997  0.213463
# 4     Bayesian Ridge Regression   0.281561  0.181203  0.208053
# 5   Stochastic Gradient Descent  -0.001987 -0.044195  0.014025
# 6                 Decision Tree   1.000000  0.147444  0.138486
# 7                 Random Forest   0.966727  0.261832  0.230169
# 8                   Extra Trees   1.000000  0.243752  0.225923
# 9                      AdaBoost   0.216695  0.079096  0.177939
# 10            Gradient Boosting   0.731090  0.249163  0.288039
# 11                 XGBRegressor   0.999593  0.261589  0.189408
# 12    Support Vector Regression   0.429156  0.134373  0.217393
# 13             Gaussian Process   1.000000  0.037274 -0.102291

# %%
AutoInt = pd.read_csv('sklearn_EmbeddingAutoInt_seed_42.csv')
AutoInt
# Out:
#                           Model  Train WPC  Test WPC    LB WPC
# 0             Linear Regression   0.343259  0.243306  0.178644
# 1              Ridge Regression   0.344642  0.247629  0.191981
# 2              Lasso Regression   0.246540  0.233198  0.172077
# 3         ElasticNet Regression   0.253473  0.235525  0.225508
# 4     Bayesian Ridge Regression   0.234992  0.221865  0.189549
# 5   Stochastic Gradient Descent   0.089460  0.078953  0.090990
# 6                 Decision Tree   1.000000  0.161686  0.147662
# 7                 Random Forest   0.965423  0.331009  0.237803
# 8                   Extra Trees   1.000000  0.294805  0.220195
# 9                      AdaBoost   0.330425  0.182133  0.115896
# 10            Gradient Boosting   0.691912  0.297530  0.145343
# 11                 XGBRegressor   0.999072  0.285865  0.217830
# 12    Support Vector Regression   0.241227  0.159711  0.153113
# 13             Gaussian Process   1.000000  0.118453  0.091876

# %%
TabTransformer = pd.read_csv('sklearn_EmbeddingTabTransformer_seed_42.csv')
TabTransformer
# Out:
#                           Model  Train WPC  Test WPC    LB WPC
# 0             Linear Regression   0.342972  0.195735  0.238400
# 1              Ridge Regression   0.343883  0.198641  0.247113
# 2              Lasso Regression   0.140746  0.146002  0.132558
# 3         ElasticNet Regression   0.142989  0.155976  0.126493
# 4     Bayesian Ridge Regression   0.173754  0.178622  0.141009
# 5   Stochastic Gradient Descent  -0.060952 -0.028541 -0.158758
# 6                 Decision Tree   1.000000  0.076758  0.037762
# 7                 Random Forest   0.964865  0.246735  0.171672
# 8                   Extra Trees   1.000000  0.239251  0.189588
# 9                      AdaBoost   0.321355  0.135384  0.067604
# 10            Gradient Boosting   0.709082  0.247083  0.221697
# 11                 XGBRegressor   0.999371  0.236768  0.149654
# 12    Support Vector Regression   0.207357  0.132802  0.138799
# 13             Gaussian Process   1.000000  0.100116  0.047516

# %%
pt_seeds = sorted(glob.glob('pytorch_tabular_seed_*.csv'))
df = pd.read_csv(pt_seeds[0])
pt_results = pd.DataFrame()
pt_results['Model'] = df['Model']
for path in pt_seeds:
    seed = int(path.split('_')[-1].split('.')[0])
    df = pd.read_csv(path)
    pt_results[str(seed)] = df['LB WPC']
pt_results
# Out:
#                Model         0         1         2         3         4  \
# 0            AutoInt  0.176417  0.171927  0.203956  0.165241  0.211268
# 1  CategoryEmbedding  0.102523  0.160420  0.081441  0.153469  0.199371
# 2     TabTransformer  0.072710  0.151507  0.071259  0.148220  0.160002
#
#          42         5         6         7         8         9
# 0  0.280448  0.201148  0.194411  0.193609  0.191629  0.194674
# 1  0.215356  0.092806  0.127988  0.184943  0.182983  0.160798
# 2  0.201933  0.066404  0.106708  0.162438  0.118407  0.110019

# %%
pt_seeds = sorted(glob.glob('sklearn_OneHotEncoder_seed_*.csv'))
df = pd.read_csv(pt_seeds[0])
pt_results = pd.DataFrame()
pt_results['Model'] = df['Model']
for path in pt_seeds:
    seed = int(path.split('_')[-1].split('.')[0])
    df = pd.read_csv(path)
    pt_results[str(seed)] = df['LB WPC']
pt_results
# Out:
#                           Model         0         1         2         3  \
# 0             Linear Regression  0.223972  0.223972  0.223972  0.223972
# 1              Ridge Regression  0.230479  0.230479  0.230479  0.230479
# 2              Lasso Regression  0.132558  0.132558  0.132558  0.132558
# 3         ElasticNet Regression  0.126045  0.126045  0.126045  0.126045
# 4     Bayesian Ridge Regression  0.131706  0.131706  0.131706  0.131706
# 5   Stochastic Gradient Descent  0.054161  0.038226  0.062863  0.129592
# 6                 Decision Tree  0.112287  0.123421  0.119987  0.164942
# 7                 Random Forest  0.177250  0.202607  0.223060  0.210264
# 8                   Extra Trees  0.206718  0.236217  0.218244  0.215000
# 9                      AdaBoost  0.205076  0.073937  0.150505  0.102626
# 10            Gradient Boosting  0.211154  0.203025  0.193371  0.198275
# 11                 XGBRegressor  0.233892  0.233892  0.233892  0.233892
# 12    Support Vector Regression  0.136682  0.136682  0.136682  0.136682
# 13             Gaussian Process  0.086913  0.086913  0.086913  0.086913
#
#            4        42         5         6         7         8         9
# 0   0.223972  0.223972  0.223972  0.223972  0.223972  0.223972  0.223972
# 1   0.230479  0.230479  0.230479  0.230479  0.230479  0.230479  0.230479
# 2   0.132558  0.132558  0.132558  0.132558  0.132558  0.132558  0.132558
# 3   0.126045  0.126045  0.126045  0.126045  0.126045  0.126045  0.126045
# 4   0.131706  0.131706  0.131706  0.131706  0.131706  0.131706  0.131706
# 5   0.037626 -0.078770 -0.174439  0.024389  0.128814  0.034210 -0.002612
# 6   0.136777  0.142747  0.124045  0.149480  0.113862  0.118930  0.188968
# 7   0.242117  0.261166  0.215813  0.211908  0.217134  0.239838  0.190178
# 8   0.241373  0.226113  0.220286  0.223784  0.232217  0.244498  0.210847
# 9   0.155737  0.142081  0.104637  0.136386  0.151989  0.169128  0.128192
# 10  0.204560  0.203545  0.205598  0.204637  0.198264  0.202797  0.201051
# 11  0.233892  0.233892  0.233892  0.233892  0.233892  0.233892  0.233892
# 12  0.136682  0.136682  0.136682  0.136682  0.136682  0.136682  0.136682
# 13  0.086913  0.086913  0.086913  0.086913  0.086913  0.086913  0.086913

# %%
pt_seeds = sorted(glob.glob('sklearn_LabelEncoder_seed_*.csv'))
df = pd.read_csv(pt_seeds[0])
pt_results = pd.DataFrame()
pt_results['Model'] = df['Model']
for path in pt_seeds:
    seed = int(path.split('_')[-1].split('.')[0])
    df = pd.read_csv(path)
    pt_results[str(seed)] = df['LB WPC']
pt_results
# Out:
#                           Model         0         1         2         3  \
# 0             Linear Regression  0.103295  0.103295  0.103295  0.103295
# 1              Ridge Regression  0.103226  0.103226  0.103226  0.103226
# 2              Lasso Regression  0.125237  0.125237  0.125237  0.125237
# 3         ElasticNet Regression  0.135864  0.135864  0.135864  0.135864
# 4     Bayesian Ridge Regression  0.136435  0.136435  0.136435  0.136435
# 5   Stochastic Gradient Descent  0.100530  0.110074  0.122307  0.115909
# 6                 Decision Tree  0.030166  0.075203  0.043180  0.064632
# 7                 Random Forest  0.185891  0.190449  0.216500  0.191740
# 8                   Extra Trees  0.116128  0.128513  0.116522  0.132217
# 9                      AdaBoost  0.144144  0.099491  0.095558  0.110055
# 10            Gradient Boosting  0.145423  0.149766  0.143568  0.149915
# 11                 XGBRegressor  0.223124  0.223124  0.223124  0.223124
# 12    Support Vector Regression  0.124128  0.124128  0.124128  0.124128
# 13             Gaussian Process  0.073724  0.073724  0.073724  0.073724
#
#            4        42         5         6         7         8         9
# 0   0.103295  0.103295  0.103295  0.103295  0.103295  0.103295  0.103295
# 1   0.103226  0.103226  0.103226  0.103226  0.103226  0.103226  0.103226
# 2   0.125237  0.125237  0.125237  0.125237  0.125237  0.125237  0.125237
# 3   0.135864  0.135864  0.135864  0.135864  0.135864  0.135864  0.135864
# 4   0.136435  0.136435  0.136435  0.136435  0.136435  0.136435  0.136435
# 5  -0.073041  0.083716  0.017550 -0.056032 -0.100158  0.116899  0.122236
# 6   0.039953  0.063233  0.032959  0.055086  0.027136  0.014554  0.062502
# 7   0.258949  0.206660  0.182896  0.193173  0.199892  0.239601  0.168303
# 8   0.099267  0.124917  0.099840  0.127966  0.146412  0.151076  0.134838
# 9   0.083755  0.124835  0.156644  0.068015  0.143287  0.154243  0.005193
# 10  0.145265  0.147784  0.146552  0.147896  0.147120  0.154781  0.142296
# 11  0.223124  0.223124  0.223124  0.223124  0.223124  0.223124  0.223124
# 12  0.124128  0.124128  0.124128  0.124128  0.124128  0.124128  0.124128
# 13  0.073724  0.073724  0.073724  0.073724  0.073724  0.073724  0.073724

# %%
pt_seeds = sorted(glob.glob('sklearn_EmbeddingCategoryEmbedding_seed_*.csv'))
df = pd.read_csv(pt_seeds[0])
pt_results = pd.DataFrame()
pt_results['Model'] = df['Model']
for path in pt_seeds:
    seed = int(path.split('_')[-1].split('.')[0])
    df = pd.read_csv(path)
    pt_results[str(seed)] = df['LB WPC']
pt_results
# Out:
#                           Model         0         1         2         3  \
# 0             Linear Regression  0.160136  0.200726  0.210698  0.232090
# 1              Ridge Regression  0.161391  0.201493  0.210612  0.210087
# 2              Lasso Regression  0.142839  0.155669  0.134289  0.162587
# 3         ElasticNet Regression  0.135332  0.182184  0.126690  0.203132
# 4     Bayesian Ridge Regression  0.122652  0.193189  0.121814  0.200920
# 5   Stochastic Gradient Descent  0.048520 -0.039159 -0.099116 -0.065455
# 6                 Decision Tree  0.077111  0.160223  0.001197  0.091528
# 7                 Random Forest  0.278827  0.272142  0.284493  0.234848
# 8                   Extra Trees  0.236921  0.239257  0.247852  0.244926
# 9                      AdaBoost  0.115729  0.166484  0.101586  0.064696
# 10            Gradient Boosting  0.194131  0.180145  0.212884  0.140242
# 11                 XGBRegressor  0.247106  0.215672  0.226602  0.260267
# 12    Support Vector Regression  0.147420  0.143571  0.168674  0.184508
# 13             Gaussian Process -0.121831  0.000261  0.058497 -0.054063
#
#            4        42         5         6         7         8         9
# 0   0.170793  0.199809  0.138733  0.194087  0.215363  0.177231  0.197508
# 1   0.187922  0.208230  0.138991  0.204986  0.210940  0.186339  0.178602
# 2   0.194239  0.246978  0.179700  0.087480  0.155752  0.207035  0.167308
# 3   0.211834  0.213463  0.186278  0.071371  0.189366  0.170434  0.175458
# 4   0.188917  0.208053  0.166299  0.072566  0.184123  0.169086  0.160616
# 5   0.088024  0.014025  0.086005  0.043870  0.036964  0.025973  0.104581
# 6  -0.009470  0.138486  0.111656  0.138695  0.182960  0.149525  0.092453
# 7   0.279963  0.230169  0.240370  0.255034  0.251573  0.283349  0.316904
# 8   0.240930  0.225923  0.220022  0.269064  0.224344  0.231254  0.220341
# 9   0.135608  0.177939  0.169686  0.073197  0.046513  0.097797  0.111728
# 10  0.241195  0.288039  0.201772  0.233683  0.208449  0.167567  0.178895
# 11  0.170314  0.189408  0.279821  0.085455  0.220761  0.180288  0.227396
# 12  0.170905  0.217393  0.188627  0.079849  0.227647  0.124010  0.224191
# 13 -0.023110 -0.102291  0.011224  0.045081  0.099771  0.042405  0.014446

# %%
pt_seeds = sorted(glob.glob('sklearn_EmbeddingAutoInt_seed_*.csv'))
df = pd.read_csv(pt_seeds[0])
pt_results = pd.DataFrame()
pt_results['Model'] = df['Model']
for path in pt_seeds:
    seed = int(path.split('_')[-1].split('.')[0])
    df = pd.read_csv(path)
    pt_results[str(seed)] = df['LB WPC']
pt_results
# Out:
#                           Model         0         1         2         3  \
# 0             Linear Regression  0.228928  0.176830  0.181845  0.144311
# 1              Ridge Regression  0.237397  0.188417  0.186381  0.137644
# 2              Lasso Regression  0.132558  0.132558  0.132558  0.132558
# 3         ElasticNet Regression  0.139365  0.162144  0.157734  0.160137
# 4     Bayesian Ridge Regression  0.158106  0.165268  0.172068  0.154938
# 5   Stochastic Gradient Descent -0.140701  0.072461 -0.125261  0.048207
# 6                 Decision Tree  0.098683  0.038561  0.208430  0.085617
# 7                 Random Forest  0.236060  0.257311  0.283005  0.220245
# 8                   Extra Trees  0.192007  0.226743  0.215541  0.203702
# 9                      AdaBoost  0.164952  0.168480  0.128626  0.069461
# 10            Gradient Boosting  0.239932  0.173410  0.154046  0.203200
# 11                 XGBRegressor  0.245738  0.209456  0.294351  0.223606
# 12    Support Vector Regression  0.145761  0.151081  0.154263  0.145116
# 13             Gaussian Process  0.020779  0.055763  0.078292  0.087085
#
#            4        42         5         6         7         8         9
# 0   0.183331  0.178644  0.191460  0.151963  0.177254  0.188968  0.161042
# 1   0.191760  0.191981  0.175517  0.160132  0.167880  0.186758  0.166886
# 2   0.132558  0.172077  0.132558  0.132558  0.132558  0.132558  0.132558
# 3   0.171753  0.225508  0.146076  0.160503  0.173687  0.126169  0.136115
# 4   0.168528  0.189549  0.153216  0.135395  0.163257  0.119727  0.140153
# 5  -0.010953  0.090990  0.195181  0.047673 -0.142001  0.022355 -0.038898
# 6   0.086861  0.147662  0.223514  0.177650  0.126955  0.039640  0.089081
# 7   0.275728  0.237803  0.227804  0.221489  0.360331  0.239718  0.250267
# 8   0.222515  0.220195  0.199728  0.174671  0.273381  0.228906  0.219902
# 9   0.179324  0.115896  0.065881  0.139716  0.109214  0.223644  0.077247
# 10  0.198387  0.145343  0.178168  0.180156  0.228169  0.174588  0.183274
# 11  0.201316  0.217830  0.230374  0.145214  0.205529  0.164676  0.160410
# 12  0.145519  0.153113  0.130843  0.133240  0.159789  0.131947  0.139655
# 13  0.052639  0.091876  0.054827  0.020156  0.048464  0.075896  0.072927

# %%
pt_seeds = sorted(glob.glob('sklearn_EmbeddingTabTransformer_seed_*.csv'))
df = pd.read_csv(pt_seeds[0])
pt_results = pd.DataFrame()
pt_results['Model'] = df['Model']
for path in pt_seeds:
    seed = int(path.split('_')[-1].split('.')[0])
    df = pd.read_csv(path)
    pt_results[str(seed)] = df['LB WPC']
pt_results
# Out:
#                           Model         0         1         2         3  \
# 0             Linear Regression  0.168532  0.158953  0.192363  0.283036
# 1              Ridge Regression  0.172103  0.164747  0.193520  0.271823
# 2              Lasso Regression  0.132558  0.132558  0.132558  0.132558
# 3         ElasticNet Regression  0.126890  0.126045  0.148642  0.126045
# 4     Bayesian Ridge Regression  0.131083  0.131183  0.130838  0.168244
# 5   Stochastic Gradient Descent -0.009052  0.025115 -0.028826  0.031842
# 6                 Decision Tree  0.167593  0.091487  0.053716  0.072002
# 7                 Random Forest  0.293621  0.268269  0.216019  0.242813
# 8                   Extra Trees  0.210763  0.234093  0.169255  0.210051
# 9                      AdaBoost  0.209957  0.154107  0.198327  0.170789
# 10            Gradient Boosting  0.241056  0.178071  0.272904  0.257610
# 11                 XGBRegressor  0.212211  0.240117  0.254492  0.214340
# 12    Support Vector Regression  0.129910  0.141949  0.135134  0.145402
# 13             Gaussian Process  0.058595  0.053283  0.041306  0.050679
#
#            4        42         5         6         7         8         9
# 0   0.199074  0.238400  0.132663  0.163614  0.204028  0.225691  0.187780
# 1   0.201177  0.247113  0.159273  0.183459  0.203612  0.224847  0.183788
# 2   0.132558  0.132558  0.132558  0.132558  0.132558  0.132558  0.132558
# 3   0.145011  0.126493  0.126045  0.134849  0.147699  0.141887  0.144651
# 4   0.156884  0.141009  0.141952  0.146949  0.172395  0.181667  0.165049
# 5   0.088841 -0.158758 -0.127967  0.051155  0.146069 -0.083529 -0.091650
# 6   0.154573  0.037762  0.080419  0.104453  0.063278  0.061449  0.163355
# 7   0.284658  0.171672  0.219240  0.219627  0.228405  0.246706  0.204942
# 8   0.202175  0.189588  0.207988  0.247888  0.176037  0.194484  0.241861
# 9   0.141819  0.067604  0.055575  0.115095  0.170970  0.175978  0.141837
# 10  0.195340  0.221697  0.213088  0.196610  0.207965  0.163959  0.221014
# 11  0.159937  0.149654  0.147344  0.192115  0.235812  0.174313  0.174735
# 12  0.141620  0.138799  0.143765  0.141466  0.149556  0.143711  0.145595
# 13  0.049682  0.047516  0.059640  0.060906  0.060698  0.077590  0.061262

# %% [markdown]
# # Let's make the Table with seed 42

# %%
path_dict = {
    'LabelEncoder': 'sklearn_LabelEncoder_seed_42.csv',
    'OneHotEncoder': 'sklearn_OneHotEncoder_seed_42.csv',
    'CategoryEmbedding': 'sklearn_EmbeddingCategoryEmbedding_seed_42.csv',
    'AutoInt': 'sklearn_EmbeddingAutoInt_seed_42.csv',
    'TabTransformer': 'sklearn_EmbeddingTabTransformer_seed_42.csv',
}

results_df = pd.DataFrame()
label_encoder = pd.read_csv(path_dict['LabelEncoder'])
results_df['Model'] = label_encoder['Model']
for key, value in path_dict.items():
    df = pd.read_csv(value)
    results_df[key] = df['LB WPC']
results_df
# Out:
#                           Model  LabelEncoder  OneHotEncoder  \
# 0             Linear Regression      0.103295       0.223972
# 1              Ridge Regression      0.103226       0.230479
# 2              Lasso Regression      0.125237       0.132558
# 3         ElasticNet Regression      0.135864       0.126045
# 4     Bayesian Ridge Regression      0.136435       0.131706
# 5   Stochastic Gradient Descent      0.083716      -0.078770
# 6                 Decision Tree      0.063233       0.142747
# 7                 Random Forest      0.206660       0.261166
# 8                   Extra Trees      0.124917       0.226113
# 9                      AdaBoost      0.124835       0.142081
# 10            Gradient Boosting      0.147784       0.203545
# 11                 XGBRegressor      0.223124       0.233892
# 12    Support Vector Regression      0.124128       0.136682
# 13             Gaussian Process      0.073724       0.086913
#
#     CategoryEmbedding   AutoInt  TabTransformer
# 0            0.199809  0.178644        0.238400
# 1            0.208230  0.191981        0.247113
# 2            0.246978  0.172077        0.132558
# 3            0.213463  0.225508        0.126493
# 4            0.208053  0.189549        0.141009
# 5            0.014025  0.090990       -0.158758
# 6            0.138486  0.147662        0.037762
# 7            0.230169  0.237803        0.171672
# 8            0.225923  0.220195        0.189588
# 9            0.177939  0.115896        0.067604
# 10           0.288039  0.145343        0.221697
# 11           0.189408  0.217830        0.149654
# 12           0.217393  0.153113        0.138799
# 13          -0.102291  0.091876        0.047516

# %% [markdown]
# # Let's make the table with mean and std for seeds from 0 to 9

# %%
path_dict = {
    'LabelEncoder': 'sklearn_LabelEncoder_seed_*.csv',
    'OneHotEncoder': 'sklearn_OneHotEncoder_seed_*.csv',
    'CategoryEmbedding': 'sklearn_EmbeddingCategoryEmbedding_seed_*.csv',
    'AutoInt': 'sklearn_EmbeddingAutoInt_seed_*.csv',
    'TabTransformer': 'sklearn_EmbeddingTabTransformer_seed_*.csv',
}

mean_df, std_df = pd.DataFrame(), pd.DataFrame()
dummy_df = pd.read_csv('sklearn_LabelEncoder_seed_42.csv')
mean_df['Model'] = dummy_df['Model']
std_df['Model'] = dummy_df['Model']
for key, value in path_dict.items():
    seeds_path = sorted(glob.glob(value))
    lb_wpc_arr = np.zeros((len(seeds_path), len(dummy_df)))
    for i, path in enumerate(seeds_path):
        df = pd.read_csv(path)
        lb_wpc_arr[i] = df['LB WPC']
    mean_df[key] = lb_wpc_arr.mean(axis=0)
    std_df[key] = lb_wpc_arr.std(axis=0)
mean_df
# Out:
#                           Model  LabelEncoder  OneHotEncoder  \
# 0             Linear Regression      0.103295       0.223972
# 1              Ridge Regression      0.103226       0.230479
# 2              Lasso Regression      0.125237       0.132558
# 3         ElasticNet Regression      0.135864       0.126045
# 4     Bayesian Ridge Regression      0.136435       0.131706
# 5   Stochastic Gradient Descent      0.050908       0.023096
# 6                 Decision Tree      0.046237       0.135950
# 7                 Random Forest      0.203096       0.217394
# 8                   Extra Trees      0.125245       0.225027
# 9                      AdaBoost      0.107747       0.138208
# 10            Gradient Boosting      0.147306       0.202389
# 11                 XGBRegressor      0.223124       0.233892
# 12    Support Vector Regression      0.124128       0.136682
# 13             Gaussian Process      0.073724       0.086913
#
#     CategoryEmbedding   AutoInt  TabTransformer
# 0            0.190652  0.178598        0.195830
# 1            0.190872  0.180978        0.200497
# 2            0.166716  0.136151        0.132558
# 3            0.169595  0.159926        0.135841
# 4            0.162567  0.156382        0.151568
# 5            0.022203  0.001732       -0.014251
# 6            0.103124  0.120241        0.095462
# 7            0.266152  0.255433        0.235998
# 8            0.236440  0.216117        0.207653
# 9            0.114633  0.131131        0.145642
# 10           0.204273  0.187152        0.215392
# 11           0.209372  0.208955        0.195915
# 12           0.170618  0.144575        0.141537
# 13          -0.002692  0.059882        0.056469

# %%
std_df
# Out:
#                           Model  LabelEncoder  OneHotEncoder  \
# 0             Linear Regression  1.387779e-17   5.551115e-17
# 1              Ridge Regression  2.775558e-17   2.775558e-17
# 2              Lasso Regression  0.000000e+00   2.775558e-17
# 3         ElasticNet Regression  2.775558e-17   2.775558e-17
# 4     Bayesian Ridge Regression  2.775558e-17   0.000000e+00
# 5   Stochastic Gradient Descent  8.341439e-02   8.294960e-02
# 6                 Decision Tree  1.824385e-02   2.290782e-02
# 7                 Random Forest  2.514824e-02   2.279834e-02
# 8                   Extra Trees  1.582172e-02   1.179860e-02
# 9                      AdaBoost  4.298648e-02   3.400304e-02
# 10            Gradient Boosting  3.257187e-03   4.429797e-03
# 11                 XGBRegressor  2.775558e-17   2.775558e-17
# 12    Support Vector Regression  1.387779e-17   2.775558e-17
# 13             Gaussian Process  0.000000e+00   0.000000e+00
#
#     CategoryEmbedding   AutoInt  TabTransformer
# 0            0.025540  0.021399        0.039996
# 1            0.022392  0.023838        0.033392
# 2            0.039489  0.011361        0.000000
# 3            0.040853  0.025157        0.009338
# 4            0.039371  0.018297        0.017368
# 5            0.062390  0.101790        0.090013
# 6            0.059059  0.059888        0.044153
# 7            0.024992  0.038486        0.034376
# 8            0.013842  0.024026        0.024323
# 9            0.042084  0.047841        0.047042
# 10           0.038280  0.027282        0.031150
# 11           0.050357  0.040281        0.036062
# 12           0.043183  0.009263        0.005128
# 13           0.064825  0.023084        0.009151

# %%
import pandas as pd
import numpy as np

# Your mean_df and std_df must be defined already

# Define encoders
traditional = ['LabelEncoder', 'OneHotEncoder']
neural = ['CategoryEmbedding', 'AutoInt', 'TabTransformer']
all_models = traditional + neural

# Store final LaTeX lines
latex_lines = []

# Header
latex_lines.append(r'\footnotesize')
latex_lines.append(r'\begin{tabular}{lccccc}')
latex_lines.append(r'\hline')
latex_lines.append(r'                 & \multicolumn{2}{c}{\textbf{Traditional encodings}}  & \multicolumn{3}{c}{\textbf{Neural Network encodings}}                             \\ \hline')
latex_lines.append(r'\textbf{Model}    & \textbf{LabelEncoder}    & \textbf{OneHotEncoder}   & \textbf{CategoryEmbedding} & \textbf{AutoInt}          & \textbf{TabTransformer}  \\ \hline')

# Process each row
for i in range(len(mean_df)):
    model_name = mean_df.loc[i, 'Model']
    values = {}
    best_val = -np.inf
    best_key = None

    for key in all_models:
        mean = mean_df.loc[i, key]
        std = std_df.loc[i, key]
        val_str = f"{mean:.3f}"
        if std > 0:
            val_str += f" ({std:.3f})"
        values[key] = val_str

        if mean > best_val:
            best_val = mean
            best_key = key

    # Check if asterisk condition is met (only for neural encoders)
    asterisk = ""
    if best_key in neural:
        label_val = mean_df.loc[i, 'LabelEncoder']
        onehot_val = mean_df.loc[i, 'OneHotEncoder']
        if (best_val >= 1.3 * label_val) and (best_val >= 1.3 * onehot_val):
            asterisk = "*"

    # Replace best value with bold
    values[best_key] = r'\textbf{' + values[best_key] + asterisk + r'}'

    row = f"{model_name} & " + " & ".join(values[key] for key in traditional + neural) + r" \\"
    latex_lines.append(row)

latex_lines.append(r'\hline')
latex_lines.append(r'\end{tabular}')
latex_lines.append(r'\caption*{\small An asterisk (*) indicates that the embedding method achieves at least 30\% better performance compared to both Label Encoding and OneHot Encoding.}')
latex_lines.append(r'\label{table:encoding_comparison}')

# Output
latex_code = "\n".join(latex_lines)
print(latex_code)
# Out:
# \footnotesize
# \begin{tabular}{lccccc}
# \hline
#                  & \multicolumn{2}{c}{\textbf{Traditional encodings}}  & \multicolumn{3}{c}{\textbf{Neural Network encodings}}                             \\ \hline
# \textbf{Model}    & \textbf{LabelEncoder}    & \textbf{OneHotEncoder}   & \textbf{CategoryEmbedding} & \textbf{AutoInt}          & \textbf{TabTransformer}  \\ \hline
# Linear Regression & 0.103 (0.000) & \textbf{0.224 (0.000)} & 0.191 (0.026) & 0.179 (0.021) & 0.196 (0.040) \\
# Ridge Regression & 0.103 (0.000) & \textbf{0.230 (0.000)} & 0.191 (0.022) & 0.181 (0.024) & 0.200 (0.033) \\
# Lasso Regression & 0.125 & 0.133 (0.000) & \textbf{0.167 (0.039)} & 0.136 (0.011) & 0.133 \\
# ElasticNet Regression & 0.136 (0.000) & 0.126 (0.000) & \textbf{0.170 (0.041)} & 0.160 (0.025) & 0.136 (0.009) \\
# Bayesian Ridge Regression & 0.136 (0.000) & 0.132 & \textbf{0.163 (0.039)} & 0.156 (0.018) & 0.152 (0.017) \\
# Stochastic Gradient Descent & \textbf{0.051 (0.083)} & 0.023 (0.083) & 0.022 (0.062) & 0.002 (0.102) & -0.014 (0.090) \\
# Decision Tree & 0.046 (0.018) & \textbf{0.136 (0.023)} & 0.103 (0.059) & 0.120 (0.060) & 0.095 (0.044) \\
# Random Forest & 0.203 (0.025) & 0.217 (0.023) & \textbf{0.266 (0.025)} & 0.255 (0.038) & 0.236 (0.034) \\
# Extra Trees & 0.125 (0.016) & 0.225 (0.012) & \textbf{0.236 (0.014)} & 0.216 (0.024) & 0.208 (0.024) \\
# AdaBoost & 0.108 (0.043) & 0.138 (0.034) & 0.115 (0.042) & 0.131 (0.048) & \textbf{0.146 (0.047)} \\
# Gradient Boosting & 0.147 (0.003) & 0.202 (0.004) & 0.204 (0.038) & 0.187 (0.027) & \textbf{0.215 (0.031)} \\
# XGBRegressor & 0.223 (0.000) & \textbf{0.234 (0.000)} & 0.209 (0.050) & 0.209 (0.040) & 0.196 (0.036) \\
# Support Vector Regression & 0.124 (0.000) & 0.137 (0.000) & \textbf{0.171 (0.043)} & 0.145 (0.009) & 0.142 (0.005) \\
# Gaussian Process & 0.074 & \textbf{0.087} & -0.003 (0.065) & 0.060 (0.023) & 0.056 (0.009) \\
# \hline
# \end{tabular}
# \caption*{\small An asterisk (*) indicates that the embedding method achieves at least 30\% better performance compared to both Label Encoding and OneHot Encoding.}
# \label{table:encoding_comparison}
